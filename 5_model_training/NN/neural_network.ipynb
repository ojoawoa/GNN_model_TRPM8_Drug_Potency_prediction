# %% [markdown]
# # Neural Network

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import mean_squared_error, accuracy_score
import pandas as pd
import os
import numpy as np
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, make_scorer, r2_score
from sklearn.metrics import (
    roc_curve, auc, confusion_matrix, ConfusionMatrixDisplay,
    accuracy_score, precision_recall_fscore_support
)
from scipy.stats import pearsonr
# Out:
# 2024-12-05 21:43:30.232728: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
problem_types = ['regression','classification'] #regression or classification
input_types = ["random_forest_elimination","correlation_variance_filter","PCA","Factor_Analysis"] #reduced features: , genetic_algorithm, PCA, Factor_Analysis, random_forest
seed = 254

# %%
def read_file(problem_type, input_file):
    """
    Read input features and recover target values (IC50 or Potency).

    Parameters:
        problem_type (str): 'regression' or 'classification'.
        input_file (str): Path to the input feature file.

    Returns:
        tuple:
            - X_indexed (pd.DataFrame): Feature DataFrame indexed by 'Molecule ChEMBL ID'.
            - target (pd.Series): Target values indexed by 'Molecule ChEMBL ID'.
    """
    # Validate problem type
    if problem_type not in {'regression', 'classification'}:
        raise ValueError("Invalid problem_type. Must be 'regression' or 'classification'.")

    # Define the target column based on problem type
    target_column = '-logIC50' if problem_type == 'regression' else 'Potency'

    # Load input features and target data
    X = pd.read_csv(input_file)
    target = pd.read_csv('../../3_train_test_split/descriptors_all.csv', usecols=['Molecule ChEMBL ID', target_column])

    # Merge target data with features based on 'Molecule ChEMBL ID'
    target = target[target['Molecule ChEMBL ID'].isin(X['Molecule ChEMBL ID'])]

    # Return original and indexed feature DataFrame, and target values as a Series
    return X.set_index('Molecule ChEMBL ID'), target.set_index('Molecule ChEMBL ID')[target_column]

# %%
def run_neural_network(problem_type, input_type, seed):
    """
    Train and evaluate a neural network for regression or classification with 5-fold cross-validation.

    Parameters:
        problem_type (str): 'regression' or 'classification'.
        input_type (str): Feature reduction scheme directory (e.g., 'PCA', 'Factor_Analysis').
        seed (int): Random seed for reproducibility.

    Returns:
        dict: Best model, test predictions, evaluation metrics, and test dataset.
    """
    tf.random.set_seed(seed)
    np.random.seed(seed)

    base_dir = f"../../4_feature_selection/{input_type}/"
    if input_type == "PCA":
        base_dir = os.path.join(base_dir, "PCA_results/PCA_components")
    elif input_type == "Factor_Analysis":
        base_dir = os.path.join(base_dir, "FA_results/selected_features")

    problem = "reg" if problem_type == "regression" else "class"
    test_file = os.path.join(base_dir, f"test_{problem}.csv")

    # Load test dataset
    X_test, y_test = read_file(problem_type, test_file)

    # For classification, encode labels
    label_encoder = None
    if problem_type == "classification":
        label_encoder = LabelEncoder()
        y_test = label_encoder.fit_transform(y_test)

    # Perform 5-fold cross-validation
    print(f"Running 5-fold cross-validation for Neural Network ({problem_type})...")
    fold_metrics = []
    best_models = []

    for fold in range(1, 6):
        train_file = os.path.join(base_dir, f"train_{problem}_{fold}.csv")
        val_file = os.path.join(base_dir, f"val_{problem}_{fold}.csv")

        X_train, y_train = read_file(problem_type, train_file)
        X_val, y_val = read_file(problem_type, val_file)

        # Encode classification labels
        if problem_type == "classification":
            y_train = label_encoder.transform(y_train)
            y_val = label_encoder.transform(y_val)

        # Define the neural network model
        model = Sequential()
        model.add(Dense(128, activation="relu", input_shape=(X_train.shape[1],)))
        model.add(Dropout(0.2))
        model.add(Dense(64, activation="relu"))
        if problem_type == "regression":
            model.add(Dense(1))  
            loss = "mean_squared_error"
            metrics = ["mean_squared_error"]
        else:
            model.add(Dense(len(np.unique(y_train)), activation="softmax"))  # Multiclass classification
            loss = "sparse_categorical_crossentropy"
            metrics = ["accuracy"]

        optimizer = Adam(learning_rate=0.001)
        model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

        # Train the model with early stopping
        early_stopping = EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)
        history = model.fit(
            X_train, y_train,
            validation_data=(X_val, y_val),
            epochs=100,
            batch_size=32,
            callbacks=[early_stopping],
            verbose=1
        )

        # Evaluate the model on validation data
        val_metrics = model.evaluate(X_val, y_val, verbose=0)
        if problem_type == "regression":
            metric = val_metrics[1]  # MSE
        else:
            metric = val_metrics[1]  # Accuracy
        fold_metrics.append(metric)
        best_models.append(model)
        print(f"Fold {fold} - Validation Metric: {metric:.4f}")

    # Average metric across folds
    avg_metric = np.mean(fold_metrics)
    print(f"Average Cross-Validation Metric: {avg_metric:.4f}")

    # Evaluate the best model on the test set
    if problem_type == "regression":
        final_model = best_models[np.argmin(fold_metrics)]  # Best model with lowest MSE
    else:
        final_model = best_models[np.argmax(fold_metrics)]  # Best model with highest accuracy

    # Evaluate the model on the test set and return results
    evaluate_model(final_model,X_test,y_test,problem_type,input_type,"Neural_Network")

    return {
        'best_model': final_model,
        'test_predictions': y_test_pred,
        'test_metric': test_metric,
        'X_test': X_test,
        'y_test': y_test
    }

# %%
def evaluate_model(final_model, X_test, y_test, problem_type, input_type, model_type):
    """
    Evaluate the model, create plots, and save performance summary and predictions.

    Parameters:
        final_model: Trained model.
        X_test (pd.DataFrame): Test feature set.
        y_test (pd.Series): True target values for the test set.
        problem_type (str): 'regression' or 'classification'.
        input_type (str): Feature reduction scheme used.
        model_type (str): Model type (default is 'random forest').

    Returns:
        None
    """
    # Generate file prefix
    file_prefix = f"{model_type}_{problem_type}_{input_type}"

    # Predictions
    y_pred = final_model.predict(X_test)

    if problem_type == "regression":
        # Calculate regression metrics
        mse = mean_squared_error(y_test, y_pred)
        r2 = r2_score(y_test, y_pred)
        pearson_corr, _ = pearsonr(y_test, y_pred)

        # Save performance summary
        performance_summary = pd.DataFrame([{
            "model_type": model_type,
            "problem_type": problem_type,
            "input_type": input_type,
            "mse": mse,
            "r2_score": r2,
            "pearson_corr": pearson_corr
        }])
        performance_summary.to_csv(f"{file_prefix}_performance_summary.csv", index=False)

        # Save predictions
        predictions = pd.DataFrame({
            "Molecule ChEMBL ID": X_test.index,
            "True IC50": y_test,
            "Predicted IC50": y_pred
        })
        predictions.to_csv(f"{file_prefix}_predictions.csv", index=False)

        # Plot Predicted vs Target
        plt.figure(figsize=(6, 6), dpi=150)
        sns.scatterplot(x=y_test, y=y_pred, alpha=0.7)
        plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color="red", linestyle="--")
        plt.xlabel("True IC50")
        plt.ylabel("Predicted IC50")
        plt.title("Predicted vs True")
        plt.savefig(f"{file_prefix}_predicted_vs_true.png")
        plt.show()

        # Plot Residuals
        residuals = y_test - y_pred
        plt.figure(figsize=(6, 6), dpi=150)
        sns.scatterplot(x=y_test, y=residuals, alpha=0.7)
        plt.axhline(0, color="red", linestyle="--")
        plt.xlabel("True IC50")
        plt.ylabel("Residuals")
        plt.title("Residual Plot")
        plt.savefig(f"{file_prefix}_residuals.png")
        plt.show()

    elif problem_type == "classification":
        # Calculate classification metrics
        accuracy = accuracy_score(y_test, y_pred)
        precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average="weighted")

        # Save performance summary
        performance_summary = pd.DataFrame([{
            "model_type": model_type,
            "problem_type": problem_type,
            "input_type": input_type,
            "accuracy": accuracy,
            "precision": precision,
            "recall": recall,
            "f1_score": f1
        }])
        performance_summary.to_csv(f"{file_prefix}_performance_summary.csv", index=False)

        # Save predictions
        predictions = pd.DataFrame({
            "Molecule ChEMBL ID": X_test.index,
            "True Potency": y_test,
            "Predicted Potency": y_pred
        })
        predictions.to_csv(f"{file_prefix}_predictions.csv", index=False)

        # Plot Confusion Matrix
        cm = confusion_matrix(y_test, y_pred)
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=final_model.classes_)
        disp.plot(cmap="Blues", values_format="d")
        plt.title("Confusion Matrix")
        plt.savefig(f"{file_prefix}_confusion_matrix.png")
        plt.show()

        # Plot ROC Curve
        if hasattr(final_model, "predict_proba"):
            y_proba = final_model.predict_proba(X_test)
            plt.figure(figsize=(8, 6), dpi=150)
            for i, class_label in enumerate(final_model.classes_):
                fpr, tpr, _ = roc_curve((y_test == class_label).astype(int), y_proba[:, i])
                roc_auc = auc(fpr, tpr)
                plt.plot(fpr, tpr, label=f"{class_label} (AUC = {roc_auc:.2f})")
            plt.plot([0, 1], [0, 1], color="red", linestyle="--")
            plt.xlabel("False Positive Rate")
            plt.ylabel("True Positive Rate")
            plt.title("ROC Curve (One-vs-Rest)")
            plt.legend()
            plt.savefig(f"{file_prefix}_roc_curve.png")
            plt.show()

# %% [markdown]
# # Train Model

# %%
for problem_type in problem_types:
    for input_type in input_types:
        print(f"Training Neural Network model for {problem_type} using {input_type} features...")
        results = run_neural_network(problem_type=problem_type, input_type=input_type, seed=seed)
        
        # Unpack results
        final_model = results["best_model"]
        X_test = results["X_test"]
        y_test = results["y_test"]
        
        # Evaluate the model
        print(f"Evaluating the model...")
        evaluate_model(final_model, X_test, y_test, problem_type, input_type, "Neural_Network")
        
        print("Training and evaluation complete")
# Out:
# Training Neural Network model for regression using random_forest_elimination features...
# Running 5-fold cross-validation for Neural Network (regression)...
# Epoch 1/100
# /Users/carmenmasri/opt/anaconda3/envs/kissim/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 206.5500 - mean_squared_error: 206.5500 - val_loss: 99.5009 - val_mean_squared_error: 99.5009
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 75.5760 - mean_squared_error: 75.5760 - val_loss: 33.8669 - val_mean_squared_error: 33.8669
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 36.1945 - mean_squared_error: 36.1945 - val_loss: 18.3187 - val_mean_squared_error: 18.3187
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24.1234 - mean_squared_error: 24.1234 - val_loss: 15.0792 - val_mean_squared_error: 15.0792
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.6333 - mean_squared_error: 17.6333 - val_loss: 13.9507 - val_mean_squared_error: 13.9507
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.7560 - mean_squared_error: 15.7560 - val_loss: 13.7209 - val_mean_squared_error: 13.7209
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.1112 - mean_squared_error: 14.1112 - val_loss: 13.7572 - val_mean_squared_error: 13.7572
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.3598 - mean_squared_error: 12.3598 - val_loss: 13.5321 - val_mean_squared_error: 13.5321
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.4150 - mean_squared_error: 13.4150 - val_loss: 13.0651 - val_mean_squared_error: 13.0651
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.1950 - mean_squared_error: 12.1950 - val_loss: 12.7973 - val_mean_squared_error: 12.7973
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8999 - mean_squared_error: 9.8999 - val_loss: 12.9159 - val_mean_squared_error: 12.9159
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9267 - mean_squared_error: 9.9267 - val_loss: 12.8143 - val_mean_squared_error: 12.8143
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.2825 - mean_squared_error: 9.2825 - val_loss: 12.5237 - val_mean_squared_error: 12.5237
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1517 - mean_squared_error: 9.1517 - val_loss: 12.6256 - val_mean_squared_error: 12.6256
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.1942 - mean_squared_error: 9.1942 - val_loss: 12.9636 - val_mean_squared_error: 12.9636
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.6637 - mean_squared_error: 8.6637 - val_loss: 13.1438 - val_mean_squared_error: 13.1438
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.1695 - mean_squared_error: 8.1695 - val_loss: 12.8948 - val_mean_squared_error: 12.8948
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.5878 - mean_squared_error: 8.5878 - val_loss: 13.0703 - val_mean_squared_error: 13.0703
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.0423 - mean_squared_error: 8.0423 - val_loss: 13.5509 - val_mean_squared_error: 13.5509
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.3716 - mean_squared_error: 7.3716 - val_loss: 13.6700 - val_mean_squared_error: 13.6700
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.2858 - mean_squared_error: 7.2858 - val_loss: 13.3380 - val_mean_squared_error: 13.3380
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.4754 - mean_squared_error: 6.4754 - val_loss: 13.8791 - val_mean_squared_error: 13.8791
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4217 - mean_squared_error: 6.4217 - val_loss: 13.9221 - val_mean_squared_error: 13.9221
# Fold 1 - Validation Metric: 12.5237
# Epoch 1/100
# /Users/carmenmasri/opt/anaconda3/envs/kissim/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 206.2780 - mean_squared_error: 206.2780 - val_loss: 103.1483 - val_mean_squared_error: 103.1483
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 77.0917 - mean_squared_error: 77.0917 - val_loss: 29.3431 - val_mean_squared_error: 29.3431
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 35.7174 - mean_squared_error: 35.7174 - val_loss: 21.3777 - val_mean_squared_error: 21.3777
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.7122 - mean_squared_error: 22.7122 - val_loss: 19.4213 - val_mean_squared_error: 19.4213
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.2749 - mean_squared_error: 19.2749 - val_loss: 14.6723 - val_mean_squared_error: 14.6723
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.6992 - mean_squared_error: 16.6992 - val_loss: 13.2608 - val_mean_squared_error: 13.2608
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.9367 - mean_squared_error: 14.9367 - val_loss: 12.3886 - val_mean_squared_error: 12.3886
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.4619 - mean_squared_error: 13.4619 - val_loss: 11.9073 - val_mean_squared_error: 11.9073
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.6291 - mean_squared_error: 12.6291 - val_loss: 11.0279 - val_mean_squared_error: 11.0279
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.1108 - mean_squared_error: 11.1108 - val_loss: 10.7557 - val_mean_squared_error: 10.7557
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.2501 - mean_squared_error: 11.2501 - val_loss: 10.6383 - val_mean_squared_error: 10.6383
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.6606 - mean_squared_error: 10.6606 - val_loss: 11.0492 - val_mean_squared_error: 11.0492
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8395 - mean_squared_error: 9.8395 - val_loss: 10.4507 - val_mean_squared_error: 10.4507
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8511 - mean_squared_error: 9.8511 - val_loss: 10.3534 - val_mean_squared_error: 10.3534
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7582 - mean_squared_error: 9.7582 - val_loss: 10.2880 - val_mean_squared_error: 10.2880
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.6718 - mean_squared_error: 8.6718 - val_loss: 10.1820 - val_mean_squared_error: 10.1820
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.8523 - mean_squared_error: 7.8523 - val_loss: 10.1345 - val_mean_squared_error: 10.1345
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.7966 - mean_squared_error: 7.7966 - val_loss: 10.1012 - val_mean_squared_error: 10.1012
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.2741 - mean_squared_error: 8.2741 - val_loss: 10.4608 - val_mean_squared_error: 10.4608
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.0026 - mean_squared_error: 8.0026 - val_loss: 10.0870 - val_mean_squared_error: 10.0870
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.6831 - mean_squared_error: 7.6831 - val_loss: 10.5041 - val_mean_squared_error: 10.5041
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.9630 - mean_squared_error: 6.9630 - val_loss: 10.2329 - val_mean_squared_error: 10.2329
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.4215 - mean_squared_error: 6.4215 - val_loss: 10.7411 - val_mean_squared_error: 10.7411
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.6471 - mean_squared_error: 6.6471 - val_loss: 10.4942 - val_mean_squared_error: 10.4942
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.6086 - mean_squared_error: 6.6086 - val_loss: 10.9882 - val_mean_squared_error: 10.9882
# Epoch 26/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.7338 - mean_squared_error: 5.7338 - val_loss: 10.9624 - val_mean_squared_error: 10.9624
# Epoch 27/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.8447 - mean_squared_error: 6.8447 - val_loss: 10.9529 - val_mean_squared_error: 10.9529
# Epoch 28/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4479 - mean_squared_error: 5.4479 - val_loss: 10.8920 - val_mean_squared_error: 10.8920
# Epoch 29/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2741 - mean_squared_error: 5.2741 - val_loss: 10.8053 - val_mean_squared_error: 10.8053
# Epoch 30/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3604 - mean_squared_error: 5.3604 - val_loss: 10.8986 - val_mean_squared_error: 10.8986
# Fold 2 - Validation Metric: 10.0870
# Epoch 1/100
# /Users/carmenmasri/opt/anaconda3/envs/kissim/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 199.8142 - mean_squared_error: 199.8142 - val_loss: 87.5548 - val_mean_squared_error: 87.5548
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 70.3733 - mean_squared_error: 70.3733 - val_loss: 40.9141 - val_mean_squared_error: 40.9141
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31.5225 - mean_squared_error: 31.5225 - val_loss: 25.4933 - val_mean_squared_error: 25.4933
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.8641 - mean_squared_error: 19.8641 - val_loss: 20.8926 - val_mean_squared_error: 20.8926
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.8238 - mean_squared_error: 17.8238 - val_loss: 19.1946 - val_mean_squared_error: 19.1946
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.4521 - mean_squared_error: 13.4521 - val_loss: 17.6463 - val_mean_squared_error: 17.6463
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.4835 - mean_squared_error: 12.4835 - val_loss: 16.5895 - val_mean_squared_error: 16.5895
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.3817 - mean_squared_error: 11.3817 - val_loss: 16.9550 - val_mean_squared_error: 16.9550
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.6779 - mean_squared_error: 10.6779 - val_loss: 16.0878 - val_mean_squared_error: 16.0878
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.0992 - mean_squared_error: 11.0992 - val_loss: 16.6912 - val_mean_squared_error: 16.6912
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.7503 - mean_squared_error: 8.7503 - val_loss: 15.9827 - val_mean_squared_error: 15.9827
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.3990 - mean_squared_error: 9.3990 - val_loss: 16.3172 - val_mean_squared_error: 16.3172
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.4228 - mean_squared_error: 9.4228 - val_loss: 16.2101 - val_mean_squared_error: 16.2101
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.8712 - mean_squared_error: 8.8712 - val_loss: 15.9383 - val_mean_squared_error: 15.9383
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.3669 - mean_squared_error: 8.3669 - val_loss: 16.0164 - val_mean_squared_error: 16.0164
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.0871 - mean_squared_error: 8.0871 - val_loss: 15.9672 - val_mean_squared_error: 15.9672
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.0423 - mean_squared_error: 8.0423 - val_loss: 15.8747 - val_mean_squared_error: 15.8747
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5948 - mean_squared_error: 6.5948 - val_loss: 15.8435 - val_mean_squared_error: 15.8435
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.8795 - mean_squared_error: 6.8795 - val_loss: 16.7421 - val_mean_squared_error: 16.7421
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.9316 - mean_squared_error: 7.9316 - val_loss: 16.3196 - val_mean_squared_error: 16.3196
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.1616 - mean_squared_error: 7.1616 - val_loss: 15.9632 - val_mean_squared_error: 15.9632
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.2927 - mean_squared_error: 6.2927 - val_loss: 15.9956 - val_mean_squared_error: 15.9956
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.6948 - mean_squared_error: 6.6948 - val_loss: 16.1483 - val_mean_squared_error: 16.1483
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.9125 - mean_squared_error: 6.9125 - val_loss: 16.0965 - val_mean_squared_error: 16.0965
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.4600 - mean_squared_error: 6.4600 - val_loss: 16.3769 - val_mean_squared_error: 16.3769
# Epoch 26/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.6907 - mean_squared_error: 5.6907 - val_loss: 16.6629 - val_mean_squared_error: 16.6629
# Epoch 27/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.9485 - mean_squared_error: 5.9485 - val_loss: 16.1757 - val_mean_squared_error: 16.1757
# Epoch 28/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.6499 - mean_squared_error: 5.6499 - val_loss: 16.3345 - val_mean_squared_error: 16.3345
# Fold 3 - Validation Metric: 15.8435
# Epoch 1/100
# /Users/carmenmasri/opt/anaconda3/envs/kissim/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 206.5846 - mean_squared_error: 206.5846 - val_loss: 112.6478 - val_mean_squared_error: 112.6478
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 80.8011 - mean_squared_error: 80.8011 - val_loss: 33.3225 - val_mean_squared_error: 33.3225
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 25.4686 - mean_squared_error: 25.4686 - val_loss: 26.8632 - val_mean_squared_error: 26.8632
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22.1606 - mean_squared_error: 22.1606 - val_loss: 20.3934 - val_mean_squared_error: 20.3934
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 16.0224 - mean_squared_error: 16.0224 - val_loss: 18.6847 - val_mean_squared_error: 18.6847
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.3038 - mean_squared_error: 13.3038 - val_loss: 17.6186 - val_mean_squared_error: 17.6186
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.1230 - mean_squared_error: 13.1230 - val_loss: 16.4438 - val_mean_squared_error: 16.4438
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.3214 - mean_squared_error: 11.3214 - val_loss: 16.3618 - val_mean_squared_error: 16.3618
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.6833 - mean_squared_error: 10.6833 - val_loss: 15.7655 - val_mean_squared_error: 15.7655
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.3365 - mean_squared_error: 10.3365 - val_loss: 15.4914 - val_mean_squared_error: 15.4914
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.4308 - mean_squared_error: 10.4308 - val_loss: 15.3109 - val_mean_squared_error: 15.3109
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6228 - mean_squared_error: 9.6228 - val_loss: 15.4879 - val_mean_squared_error: 15.4879
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.2818 - mean_squared_error: 9.2818 - val_loss: 15.3275 - val_mean_squared_error: 15.3275
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.6011 - mean_squared_error: 8.6011 - val_loss: 15.5239 - val_mean_squared_error: 15.5239
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.9665 - mean_squared_error: 7.9665 - val_loss: 15.0247 - val_mean_squared_error: 15.0247
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.6420 - mean_squared_error: 8.6420 - val_loss: 15.0978 - val_mean_squared_error: 15.0978
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.8466 - mean_squared_error: 7.8466 - val_loss: 15.4140 - val_mean_squared_error: 15.4140
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.9523 - mean_squared_error: 7.9523 - val_loss: 14.8059 - val_mean_squared_error: 14.8059
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.9520 - mean_squared_error: 6.9520 - val_loss: 14.7987 - val_mean_squared_error: 14.7987
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.4338 - mean_squared_error: 7.4338 - val_loss: 14.5001 - val_mean_squared_error: 14.5001
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7586 - mean_squared_error: 6.7586 - val_loss: 14.4464 - val_mean_squared_error: 14.4464
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.2702 - mean_squared_error: 7.2702 - val_loss: 14.7237 - val_mean_squared_error: 14.7237
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.6304 - mean_squared_error: 6.6304 - val_loss: 14.3611 - val_mean_squared_error: 14.3611
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0648 - mean_squared_error: 6.0648 - val_loss: 14.8817 - val_mean_squared_error: 14.8817
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0267 - mean_squared_error: 6.0267 - val_loss: 14.9858 - val_mean_squared_error: 14.9858
# Epoch 26/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.7604 - mean_squared_error: 5.7604 - val_loss: 14.8424 - val_mean_squared_error: 14.8424
# Epoch 27/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0360 - mean_squared_error: 6.0360 - val_loss: 14.8097 - val_mean_squared_error: 14.8097
# Epoch 28/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1523 - mean_squared_error: 5.1523 - val_loss: 15.0718 - val_mean_squared_error: 15.0718
# Epoch 29/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9395 - mean_squared_error: 4.9395 - val_loss: 14.6368 - val_mean_squared_error: 14.6368
# Epoch 30/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2002 - mean_squared_error: 5.2002 - val_loss: 15.0446 - val_mean_squared_error: 15.0446
# Epoch 31/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2027 - mean_squared_error: 5.2027 - val_loss: 14.8783 - val_mean_squared_error: 14.8783
# Epoch 32/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5254 - mean_squared_error: 4.5254 - val_loss: 15.3723 - val_mean_squared_error: 15.3723
# Epoch 33/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.2509 - mean_squared_error: 5.2509 - val_loss: 14.4654 - val_mean_squared_error: 14.4654
# Fold 4 - Validation Metric: 14.3611
# Epoch 1/100
# /Users/carmenmasri/opt/anaconda3/envs/kissim/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 194.0665 - mean_squared_error: 194.0665 - val_loss: 103.9105 - val_mean_squared_error: 103.9105
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 70.1007 - mean_squared_error: 70.1007 - val_loss: 40.8532 - val_mean_squared_error: 40.8532
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 35.2873 - mean_squared_error: 35.2873 - val_loss: 22.7941 - val_mean_squared_error: 22.7941
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.0539 - mean_squared_error: 19.0539 - val_loss: 19.1505 - val_mean_squared_error: 19.1505
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.7990 - mean_squared_error: 15.7990 - val_loss: 16.5371 - val_mean_squared_error: 16.5371
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.2033 - mean_squared_error: 12.2033 - val_loss: 15.5173 - val_mean_squared_error: 15.5173
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.7147 - mean_squared_error: 11.7147 - val_loss: 14.9288 - val_mean_squared_error: 14.9288
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.6245 - mean_squared_error: 11.6245 - val_loss: 14.7291 - val_mean_squared_error: 14.7291
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.8532 - mean_squared_error: 10.8532 - val_loss: 14.4847 - val_mean_squared_error: 14.4847
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7524 - mean_squared_error: 9.7524 - val_loss: 14.2695 - val_mean_squared_error: 14.2695
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.3845 - mean_squared_error: 9.3845 - val_loss: 13.8629 - val_mean_squared_error: 13.8629
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.4469 - mean_squared_error: 9.4469 - val_loss: 14.0952 - val_mean_squared_error: 14.0952
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.3180 - mean_squared_error: 9.3180 - val_loss: 13.4852 - val_mean_squared_error: 13.4852
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.2628 - mean_squared_error: 8.2628 - val_loss: 13.7825 - val_mean_squared_error: 13.7825
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.3295 - mean_squared_error: 8.3295 - val_loss: 13.7779 - val_mean_squared_error: 13.7779
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.1655 - mean_squared_error: 7.1655 - val_loss: 13.4484 - val_mean_squared_error: 13.4484
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.8947 - mean_squared_error: 7.8947 - val_loss: 13.3633 - val_mean_squared_error: 13.3633
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.6453 - mean_squared_error: 7.6453 - val_loss: 13.4342 - val_mean_squared_error: 13.4342
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.2546 - mean_squared_error: 7.2546 - val_loss: 13.2679 - val_mean_squared_error: 13.2679
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.6231 - mean_squared_error: 6.6231 - val_loss: 13.1831 - val_mean_squared_error: 13.1831
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.0062 - mean_squared_error: 7.0062 - val_loss: 13.3954 - val_mean_squared_error: 13.3954
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.8207 - mean_squared_error: 6.8207 - val_loss: 13.2185 - val_mean_squared_error: 13.2185
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.2806 - mean_squared_error: 7.2806 - val_loss: 13.5172 - val_mean_squared_error: 13.5172
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.0127 - mean_squared_error: 7.0127 - val_loss: 12.8937 - val_mean_squared_error: 12.8937
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.9065 - mean_squared_error: 5.9065 - val_loss: 13.1741 - val_mean_squared_error: 13.1741
# Epoch 26/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1639 - mean_squared_error: 5.1639 - val_loss: 13.8068 - val_mean_squared_error: 13.8068
# Epoch 27/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.7599 - mean_squared_error: 5.7599 - val_loss: 12.8063 - val_mean_squared_error: 12.8063
# Epoch 28/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.7124 - mean_squared_error: 5.7124 - val_loss: 13.4069 - val_mean_squared_error: 13.4069
# Epoch 29/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1069 - mean_squared_error: 5.1069 - val_loss: 12.9171 - val_mean_squared_error: 12.9171
# Epoch 30/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.4204 - mean_squared_error: 5.4204 - val_loss: 12.8875 - val_mean_squared_error: 12.8875
# Epoch 31/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7260 - mean_squared_error: 4.7260 - val_loss: 13.2340 - val_mean_squared_error: 13.2340
# Epoch 32/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3155 - mean_squared_error: 5.3155 - val_loss: 13.3334 - val_mean_squared_error: 13.3334
# Epoch 33/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1342 - mean_squared_error: 5.1342 - val_loss: 13.0648 - val_mean_squared_error: 13.0648
# Epoch 34/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9483 - mean_squared_error: 4.9483 - val_loss: 12.4690 - val_mean_squared_error: 12.4690
# Epoch 35/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4927 - mean_squared_error: 4.4927 - val_loss: 13.1278 - val_mean_squared_error: 13.1278
# Epoch 36/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4756 - mean_squared_error: 4.4756 - val_loss: 13.0121 - val_mean_squared_error: 13.0121
# Epoch 37/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5520 - mean_squared_error: 4.5520 - val_loss: 11.9135 - val_mean_squared_error: 11.9135
# Epoch 38/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3709 - mean_squared_error: 4.3709 - val_loss: 11.9833 - val_mean_squared_error: 11.9833
# Epoch 39/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3835 - mean_squared_error: 4.3835 - val_loss: 13.5915 - val_mean_squared_error: 13.5915
# Epoch 40/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3464 - mean_squared_error: 4.3464 - val_loss: 13.8688 - val_mean_squared_error: 13.8688
# Epoch 41/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7398 - mean_squared_error: 3.7398 - val_loss: 12.6224 - val_mean_squared_error: 12.6224
# Epoch 42/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4666 - mean_squared_error: 4.4666 - val_loss: 12.1764 - val_mean_squared_error: 12.1764
# Epoch 43/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2513 - mean_squared_error: 4.2513 - val_loss: 12.7057 - val_mean_squared_error: 12.7057
# Epoch 44/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0776 - mean_squared_error: 4.0776 - val_loss: 13.0847 - val_mean_squared_error: 13.0847
# Epoch 45/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9579 - mean_squared_error: 3.9579 - val_loss: 13.0069 - val_mean_squared_error: 13.0069
# Epoch 46/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8356 - mean_squared_error: 3.8356 - val_loss: 13.2916 - val_mean_squared_error: 13.2916
# Epoch 47/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9598 - mean_squared_error: 3.9598 - val_loss: 13.3346 - val_mean_squared_error: 13.3346
# Fold 5 - Validation Metric: 11.9135
# Average Cross-Validation Metric: 12.9458
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# /var/folders/jg/f84gjnc17d51qj6zy5cb71lh0000gq/T/ipykernel_9576/2936731095.py:26: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   pearson_corr, _ = pearsonr(y_test, y_pred)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 4
#       2 for input_type in input_types:
#       3     print(f"Training Neural Network model for {problem_type} using {input_type} features...")
# ----> 4     results = run_neural_network(problem_type=problem_type, input_type=input_type, seed=seed)
#       6     # Unpack results
#       7     final_model = results["best_model"]
#
# Cell In[4], line 100, in run_neural_network(problem_type, input_type, seed)
#      97     final_model = best_models[np.argmax(fold_metrics)]  # Best model with highest accuracy
#      99 # Evaluate the model on the test set and return results
# --> 100 evaluate_model(final_model,X_test,y_test,problem_type,input_type,"Neural_Network")
#     102 return {
#     103     'best_model': final_model,
#     104     'test_predictions': y_test_pred,
#    (...)
#     107     'y_test': y_test
#     108 }
#
# Cell In[5], line 40, in evaluate_model(final_model, X_test, y_test, problem_type, input_type, model_type)
#      37 performance_summary.to_csv(f"{file_prefix}_performance_summary.csv", index=False)
#      39 # Save predictions
# ---> 40 predictions = pd.DataFrame({
#      41     "Molecule ChEMBL ID": X_test.index,
#      42     "True IC50": y_test,
#      43     "Predicted IC50": y_pred
#      44 })
#      45 predictions.to_csv(f"{file_prefix}_predictions.csv", index=False)
#      47 # Plot Predicted vs Target
#
# File ~/opt/anaconda3/envs/kissim/lib/python3.10/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File ~/opt/anaconda3/envs/kissim/lib/python3.10/site-packages/pandas/core/internals/construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/opt/anaconda3/envs/kissim/lib/python3.10/site-packages/pandas/core/internals/construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File ~/opt/anaconda3/envs/kissim/lib/python3.10/site-packages/pandas/core/internals/construction.py:664, in _extract_index(data)
#     662         raw_lengths.append(len(val))
#     663     elif isinstance(val, np.ndarray) and val.ndim > 1:
# --> 664         raise ValueError("Per-column arrays must each be 1-dimensional")
#     666 if not indexes and not raw_lengths:
#     667     raise ValueError("If using all scalar values, you must pass an index")
#
# ValueError: Per-column arrays must each be 1-dimensional
