# %%
import os
import subprocess
from sklearn.preprocessing import StandardScaler
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem

# %% [markdown]
# # Generate Orca Inputs

# %%
def calculate_multiplicity(mol):
    """
    Calculate the multiplicity based on the number of unpaired (radical) electrons.
    
    Args:
    mol (rdkit.Chem.Mol): RDKit molecule object.
    
    Returns:
    multiplicity (int): The calculated multiplicity of the molecule.
    """
    n_radical_electrons = 0
    # Loop through atoms and sum the number of unpaired electrons
    for atom in mol.GetAtoms():
        n_radical_electrons += atom.GetNumRadicalElectrons()

    # Calculate multiplicity: Multiplicity = n_radical_electrons + 1
    if n_radical_electrons == 0:
        multiplicity = 1  # Singlet (all electrons paired)
    else:
        multiplicity = n_radical_electrons + 1  # Doublet, triplet, etc.
    
    return multiplicity

def determine_charge_and_multiplicity(mol):
    """
    Determines the formal charge and the multiplicity of the molecule.
    
    Args:
    mol (rdkit.Chem.Mol): RDKit molecule object.
    
    Returns:
    charge (int): The formal charge of the molecule.
    multiplicity (int): The calculated multiplicity based on the number of radical electrons.
    """
    # Determine the formal charge using RDKit's built-in function
    charge = Chem.GetFormalCharge(mol)

    # Calculate multiplicity using the custom function
    multiplicity = calculate_multiplicity(mol)

    return charge, multiplicity


def smiles_to_orca_input(smiles_string, chembl_id, output_inp_file, method="B3LYP", basis_set="6-31G*"):
    """
    Converts a SMILES string to a 3D structure, determines charge/multiplicity, and generates ORCA input file.
    
    Args:
    smiles_string (str): SMILES string representing the molecule.
    chembl_id (str): Identifier for the molecule (used in file naming).
    output_inp_file (str): The name of the ORCA input file to be generated.
    method (str): Quantum chemistry method (default is B3LYP).
    basis_set (str): Basis set (default is 6-31G*).
    """
    mol = Chem.MolFromSmiles(smiles_string)
    mol = Chem.AddHs(mol)  # Add hydrogens
    AllChem.EmbedMolecule(mol, AllChem.ETKDG())  # Generate 3D coordinates
    AllChem.UFFOptimizeMolecule(mol)  # Optimize geometry

    # Determine the charge and multiplicity
    charge, multiplicity = determine_charge_and_multiplicity(mol)

    # Generate ORCA input file content 
    orca_input = f"! {method} {basis_set} SP\n\n* xyz {charge} {multiplicity}\n"
    
    # Write atomic coordinates to the ORCA input file
    with open(output_inp_file, 'w') as inp_file:
        inp_file.write(orca_input)
        for atom in mol.GetAtoms():
            pos = mol.GetConformer().GetAtomPosition(atom.GetIdx())
            symbol = atom.GetSymbol()
            inp_file.write(f"{symbol} {pos.x:.4f} {pos.y:.4f} {pos.z:.4f}\n")
        inp_file.write("*\n")

    print(f"ORCA input file '{output_inp_file}' generated successfully with charge {charge} and multiplicity {multiplicity}.")


def process_csv(csv_file):
    """
    Processes a CSV file containing SMILES strings and ChEMBL IDs to generate ORCA input files.
    
    Args:
    csv_file (str): Path to the CSV file.
    """
    # Read the CSV file into a DataFrame
    df = pd.read_csv(csv_file)

    # extract SMILES from the 6th column (index 5) and ChEMBL IDs from 1st column (index 0)
    for index, row in df.iterrows():
        chembl_id = row[0]  # ChEMBL ID from the first column
        smiles = row[5]  # SMILES from the 6th column
        
        # Define output filenames using the ChEMBL ID
        output_inp_file = f"{out_dir}/{chembl_id}.inp"
        
        print(f"Processing {chembl_id}: {smiles}")
        
        # Convert SMILES to ORCA input
        smiles_to_orca_input(smiles, chembl_id, output_inp_file)

# %%
#Process a CSV file
out_dir = "orca_inputs"
if not os.path.exists(out_dir):
    os.makedirs(out_dir)
    print(f"Directory '{out_dir}' created.")
else:
    print(f"Directory '{out_dir}' already exists.")
    
csv_file = "../1_preprocess/TRPM8-homosapien-compounds-activities-processed.csv"  # Update this with the actual path to your CSV file


process_csv(csv_file)
# Out:
# Processing CHEMBL3235962: N#Cc1cccc(NC(=O)N2CCc3ccccc3[C@H]2c2ccc(C(F)(F)F)cc2)c1
# ORCA input file 'CHEMBL3235962.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3235983: C[C@H](NC(=O)N1CCc2ccccc2[C@H]1c1ccc(C(F)(F)F)c(F)c1)C(F)(F)F
# ORCA input file 'CHEMBL3235983.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL1650511: FC(F)(F)c1ccccc1-c1cc(C(F)(F)F)c2[nH]c(C3=NOC4(CCCCC4)C3)nc2c1
# ORCA input file 'CHEMBL1650511.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL2443068: O=C1CC2(CCN(C(=O)Nc3ccc(C(F)(F)F)cc3)CC2)Oc2c(Cl)cccc21
# ORCA input file 'CHEMBL2443068.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3959823: Cc1cccc(CN(C(=O)c2ccccc2)[C@@H](C(N)=O)c2ccccc2)c1
# ORCA input file 'CHEMBL3959823.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3944840: C[C@H](c1cccc(Cl)c1)N(C(=O)c1ccccc1O)[C@@H](C(N)=O)c1ccccc1
# ORCA input file 'CHEMBL3944840.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4644158: O=C(NCc1ccc(F)cc1)[C@@H]1Cc2c([nH]c3ccccc23)CN1
# ORCA input file 'CHEMBL4644158.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4649088: O=C1N[C@H](Cc2ccccc2)C(=O)N2Cc3[nH]c4ccccc4c3C[C@@H]12
# ORCA input file 'CHEMBL4649088.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL2443089: O=C(Nc1ccc(C(F)(F)F)cc1Cl)N1CCC2(CCc3cccc(Cl)c3O2)CC1
# ORCA input file 'CHEMBL2443089.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3985375: Cc1ccc(-c2csc(NC(=O)Cc3cccc4c3c(=O)n(C)c(=O)n4C)n2)cc1
# ORCA input file 'CHEMBL3985375.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3897802: Cn1c(=O)c2c(CC(=O)Nc3nc(-c4ccc(F)c(C(F)(F)F)c4)cs3)cccc2n(C)c1=O
# ORCA input file 'CHEMBL3897802.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3897467: Cn1c(=O)c2c(CC(=O)Nc3nc(-c4ccc(Cl)c(C(F)(F)F)c4)cs3)cccc2n(C)c1=O
# ORCA input file 'CHEMBL3897467.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3936454: Cc1oc2c(c1CC(=O)Nc1nc(-c3ccc(F)c(C(F)(F)F)c3)cs1)c(=O)n(C)c(=O)n2C
# ORCA input file 'CHEMBL3936454.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL391997: Oc1cc2c(cc1O)CN(C(=S)NCCc1ccc(Cl)cc1)CCC2
# ORCA input file 'CHEMBL391997.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3979456: Cn1c(=O)c2c(CC(=O)Nc3nc(-c4ccc(F)c(C(F)(F)F)c4F)cs3)ccnc2n(C)c1=O
# ORCA input file 'CHEMBL3979456.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682545: CCOC(C)(c1ccc(CN(c2ncc3ccccc3c2C)S(=O)(=O)c2ccc(C(=O)O)cc2)cc1)C(F)(F)F
# ORCA input file 'CHEMBL3682545.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682546: Cc1cc2ccccc2nc1N(Cc1ccc(OC(F)(F)F)cc1)S(=O)(=O)c1ccc(C(=O)O)cc1
# ORCA input file 'CHEMBL3682546.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682562: Cc1c(N(Cc2ccc(OC3CC3)cc2)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3682562.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682573: Cc1c(N(Cc2ccc(-c3ccccc3)nc2)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3682573.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682589: O=C(O)c1ccc(S(=O)(=O)N(Cc2ccc(OC(F)(F)F)cc2)c2ncc3ccccc3c2C2CC2)cc1
# ORCA input file 'CHEMBL3682589.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682604: Cc1c(N(Cc2nc3ccccc3o2)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3682604.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682606: Cc1c(N(Cc2ccc(OC(F)(F)F)cc2)S(=O)(=O)c2ccc(C(=O)O)cc2)nc(Br)c2ccccc12
# ORCA input file 'CHEMBL3682606.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682617: Cc1c(N(Cc2ccc(OC(F)(F)F)cc2)S(=O)(=O)c2ccc(C(=O)[O-])cc2)nc2ccccc2c1Cl
# ORCA input file 'CHEMBL3682617.inp' generated successfully with charge -1 and multiplicity 1.
# Processing CHEMBL3687329: Cc1c(N(Cc2ccc(OC(F)(F)F)cc2)S(=O)(=O)c2ccc(C(=O)[O-])cc2)ncc2ncccc12
# ORCA input file 'CHEMBL3687329.inp' generated successfully with charge -1 and multiplicity 1.
# Processing CHEMBL3687338: Cc1c(N(Cc2cc3cccc(Cl)c3n2C)S(=O)(=O)c2ccc(C(=O)[O-])cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3687338.inp' generated successfully with charge -1 and multiplicity 1.
# Processing CHEMBL275628: NCCc1c[nH]c2ccc(F)cc12
# ORCA input file 'CHEMBL275628.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3971179: C[C@H](c1cc(F)cc(F)c1)N(C(=O)c1ccccc1)[C@@H](C(N)=O)c1ccccc1
# ORCA input file 'CHEMBL3971179.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3924373: CCc1sc2c(c1CC(=O)Nc1nc(-c3cc(F)c(OC(F)F)c(F)c3)cs1)c(=O)n(C)c(=O)n2C
# ORCA input file 'CHEMBL3924373.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3905801: Cn1c(=O)c2c(CC(=O)Nc3nc(-c4ccc(F)c(C(F)(F)F)c4F)cs3)csc2n(C)c1=O
# ORCA input file 'CHEMBL3905801.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL1289952: CCOC(=O)NCCc1c[nH]c2ccc(OCc3ccccc3)cc12
# ORCA input file 'CHEMBL1289952.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3935896: Cc1cccc(C(=O)N([C@H](C)c2cccc(Cl)c2)[C@@H](C(N)=O)c2ccccc2)c1
# ORCA input file 'CHEMBL3935896.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3926952: C[C@H](c1cc(F)cc(Cl)c1)N(C(=O)c1ccccc1)[C@@H](C(N)=O)c1ccccc1
# ORCA input file 'CHEMBL3926952.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL256087: CC1CCC(C(C)C)C(O)C1
# ORCA input file 'CHEMBL256087.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3984932: Cn1c(=O)c2c(CC(=O)Nc3nc(-c4cc(F)cc(C(F)(F)F)c4)cs3)nsc2n(C)c1=O
# ORCA input file 'CHEMBL3984932.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3353585: N#Cc1cc(C(F)(F)F)cnc1N(Cc1ccccc1)S(=O)(=O)c1ccc(C(=O)O)cc1
# ORCA input file 'CHEMBL3353585.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3353580: N#Cc1cnc(N(Cc2ccccc2)S(=O)(=O)c2ccc(C(=O)O)cc2)c(Cl)c1
# ORCA input file 'CHEMBL3353580.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3353579: O=C(O)c1ccc(S(=O)(=O)N(Cc2ccccc2)c2ncc(Cl)cc2Cl)cc1
# ORCA input file 'CHEMBL3353579.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3235967: CC(C)(C)NC(=O)N1CCc2ccccc2[C@H]1c1ccc(C(F)(F)F)cc1
# ORCA input file 'CHEMBL3235967.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3235959: O=C(Nc1ccccc1F)N1CCc2ccccc2[C@H]1c1ccc(C(F)(F)F)cc1
# ORCA input file 'CHEMBL3235959.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL1288652: NCCc1c[nH]c2ccc(OCc3ccccc3)cc12
# ORCA input file 'CHEMBL1288652.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3353606: O=C(O)c1ccc(S(=O)(=O)N(Cc2ccc3occc3c2)c2ncc(C(F)(F)F)cc2Cl)cc1
# ORCA input file 'CHEMBL3353606.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3904770: Cc1oc2c(c1CC(=O)Nc1nc(-c3cc(F)c(OCC(C)(C)C)c(F)c3)cs1)c(=O)n(C)c(=O)n2C
# ORCA input file 'CHEMBL3904770.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3987098: Cc1oc2c(c1CC(=O)/N=c1\scc(-c3ccc(OC(F)(F)F)c(Cl)c3)n1COC(=O)[C@@H](N)C(C)C)c(=O)n(C)c(=O)n2C
# ORCA input file 'CHEMBL3987098.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3936873: COc1cc(CN(C(=O)c2cccs2)[C@@H](C(N)=O)c2ccccc2)ccc1OCc1ccc(F)cc1
# ORCA input file 'CHEMBL3936873.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3900018: Cc1cccc(COc2ccccc2C(=O)N(CCCN)Cc2cccs2)c1
# ORCA input file 'CHEMBL3900018.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3233042: CC1(c2ccc(C(F)(F)F)cc2)c2ccccc2CCN1C(=O)Nc1ccc(F)cc1
# ORCA input file 'CHEMBL3233042.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4237383: O=C(N[C@@H](c1ccc(C(F)(F)F)c(F)c1)c1ccccc1C(F)(F)F)c1ccc2cccnc2c1
# ORCA input file 'CHEMBL4237383.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4246304: O=C(N[C@@H](c1cnc2ccccc2c1)c1ncccc1C(F)(F)F)c1ccc2cccnc2c1
# ORCA input file 'CHEMBL4246304.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4250626: O=C(O)c1ccc(C(=O)N[C@@H](c2ccc(OC(F)(F)F)c(F)c2)c2ncccc2F)cc1
# ORCA input file 'CHEMBL4250626.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4243837: O=C(N[C@@H](c1ccc(OC(F)(F)F)c(F)c1)c1ncccc1F)c1ccc(=O)[nH]c1
# ORCA input file 'CHEMBL4243837.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3921886: Cn1c(=O)c2c(CC(=O)Nc3nc(-c4ccc(Br)cc4)cs3)cccc2n(C)c1=O
# ORCA input file 'CHEMBL3921886.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3956711: Cn1c(=O)c2c(CC(=O)Nc3nc(-c4cccc(C(F)(F)F)c4)cs3)cccc2n(C)c1=O
# ORCA input file 'CHEMBL3956711.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3977240: Cc1oc2c(c1CC(=O)Nc1nc(-c3ccc(F)c(OC(F)(F)F)c3)cs1)c(=O)n(C)c(=O)n2C
# ORCA input file 'CHEMBL3977240.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL1939972: COCCCOc1cccc(C2NC(=S)NC3=C2C(=O)c2ccccc23)c1
# ORCA input file 'CHEMBL1939972.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL2443064: O=C(Nc1ccc(C(F)(F)F)cc1)N1CCC2(CCc3cc(F)cc(Cl)c3O2)CC1
# ORCA input file 'CHEMBL2443064.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL2442051: NCCN(Cc1cccs1)C(=O)c1ccccc1OCc1ccccc1
# ORCA input file 'CHEMBL2442051.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL2442016: CCN(C(=O)c1ccccc1OCc1ccccc1Cl)[C@H]1CCC[C@@H](N)C1
# ORCA input file 'CHEMBL2442016.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3235975: O=C(Nc1ccc(F)cc1)N1CCc2ccncc2C1c1ccc(C(F)(F)F)cc1
# ORCA input file 'CHEMBL3235975.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3235978: O=C(Nc1ccc(F)cc1)N1CCc2nccnc2[C@H]1c1ccc(C(F)(F)F)cc1
# ORCA input file 'CHEMBL3235978.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL441472: CC(C)(C)c1ccc(NC(=O)N2CCN(c3ncccc3Cl)CC2)cc1
# ORCA input file 'CHEMBL441472.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682597: Cc1c(N(Cc2ccc3ccn(C)c3c2)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3682597.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682600: Cc1c(N(Cc2ccc(OC(F)(F)F)cc2)S(=O)(=O)c2ccc(C(N)=O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3682600.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687366: Cc1c(N(Cc2cc3cc(F)cc(F)c3s2)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3687366.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687390: COC(C)(c1ccc(CN(c2ncc3ccccc3c2C)S(=O)(=O)c2ccc(C(=O)O)cc2)cc1F)C(F)(F)F
# ORCA input file 'CHEMBL3687390.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682610: Cc1cc2cccc(Cl)c2nc1N(Cc1ccc(OC(F)(F)F)cc1)S(=O)(=O)c1ccc(C(=O)O)cc1
# ORCA input file 'CHEMBL3682610.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687324: CC(C)c1nc(N(Cc2ccc(OC(F)(F)F)cc2)S(=O)(=O)c2ccc(C(=O)O)cc2)c(C(C)C)c2ccccc12
# ORCA input file 'CHEMBL3687324.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687353: Cc1c(N(Cc2ccc(C(F)(F)C3CC3)c(Cl)c2)S(=O)(=O)c2ccc(C(=O)O)cc2)nc(C2CC2)c2ccccc12
# ORCA input file 'CHEMBL3687353.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687358: O=C(O)c1ccc(S(=O)(=O)N(c2ncc3ccccc3c2C2CC2)C2CCc3cc(OC(F)(F)F)ccc32)cc1
# ORCA input file 'CHEMBL3687358.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682541: Cn1ccc2c(Cl)cnc(N(Cc3ccc(OC(F)(F)F)cc3)S(=O)(=O)c3ccc(C(=O)[O-])cc3)c21
# ORCA input file 'CHEMBL3682541.inp' generated successfully with charge -1 and multiplicity 1.
# Processing CHEMBL3682542: Cc1c(N(Cc2ccc(-c3ccc(F)cc3)cc2)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3682542.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682554: Cc1c(N(Cc2cccc3ccccc23)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3682554.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687412: NC(=O)c1ccc(S(=O)(=O)N(Cc2ccc(OC(F)(F)F)cc2)c2ncc3ccccc3c2C2CC2)cc1
# ORCA input file 'CHEMBL3687412.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3899453: Cc1oc2c(c1CC(=O)Nc1nc(-c3cc(F)c(C(F)(F)F)c(F)c3)cs1)c(=O)n(C)c(=O)n2C
# ORCA input file 'CHEMBL3899453.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3920312: Cc1oc2c(c1CC(=O)Nc1nc(-c3cc(Cl)c(OCC(C)C)c(Cl)c3)cs1)c(=O)n(C)c(=O)n2C
# ORCA input file 'CHEMBL3920312.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4780270: C[C@H](c1cc(F)cc(F)c1)N(C(=O)c1ccccc1N)[C@@H](C(N)=O)c1ccccc1
# ORCA input file 'CHEMBL4780270.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4749601: NC(=O)[C@@H](c1ccccc1)N(C(=O)c1ccccc1)[C@@H]1CCc2c(F)cc(Cl)cc21
# ORCA input file 'CHEMBL4749601.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4763338: NC(=O)[C@@H](c1ccccc1)N(C(=O)c1ccccc1)[C@@H]1COc2ccccc21
# ORCA input file 'CHEMBL4763338.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4754910: NC(=O)[C@@H](c1ccccc1)N(C(=O)c1ccccc1)[C@@H]1CCc2ncccc21
# ORCA input file 'CHEMBL4754910.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4764800: C[C@H](c1cc(F)c(F)c(F)c1)N(C(=O)c1ccccc1)[C@@H](C(N)=O)c1ccccc1
# ORCA input file 'CHEMBL4764800.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687391: CCOC(C)(c1ccc(CN(c2ncc3ccccc3c2C)S(=O)(=O)c2ccc(C(=O)O)cc2)cc1F)C(F)(F)F
# ORCA input file 'CHEMBL3687391.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687402: CC(C)c1nc(N(Cc2ccc(OC(F)(F)F)cc2)S(=O)(=O)c2ccc(C(=O)O)cc2)c(C2CC2)c2ccccc12
# ORCA input file 'CHEMBL3687402.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3939180: Cn1c(=O)c2c(CC(=O)Nc3nc(-c4ccc(F)cc4F)cs3)cccc2n(C)c1=O
# ORCA input file 'CHEMBL3939180.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3935604: Cn1c(=O)c2c(CC(=O)Nc3ccn(-c4cccc(C(F)(F)F)c4)n3)cccc2n(C)c1=O
# ORCA input file 'CHEMBL3935604.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3958453: Cn1c(=O)c2c(CC(=O)Nc3nc(-c4cccc(F)c4F)cs3)cccc2n(C)c1=O
# ORCA input file 'CHEMBL3958453.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3906012: Cn1c(=O)c2c(CC(=O)Nc3nc(-c4cc(F)c(OCC(F)(F)F)c(F)c4)cs3)cccc2n(C)c1=O
# ORCA input file 'CHEMBL3906012.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3981381: Cn1nc2c(c1CC(=O)Nc1nc(-c3ccc(C(F)(F)F)c(F)c3)cs1)c(=O)n(C)c(=O)n2C
# ORCA input file 'CHEMBL3981381.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4647674: O=C1[C@@H]2Cc3c([nH]c4ccccc34)[C@@H](c3ccc(Cl)cc3)N2C(=O)N1Cc1ccc(F)cc1
# ORCA input file 'CHEMBL4647674.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682586: Cc1c(N(Cc2ccc(OC(F)(F)F)cc2)S(=O)(=O)c2ccc(C(=O)O)cc2)nc(N2CCCC2)c2ccccc12
# ORCA input file 'CHEMBL3682586.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682596: Cc1c(N(Cc2ccc3cc[nH]c3c2)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3682596.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687330: Cc1c(N(Cc2ccc(OC(F)(F)F)cc2)S(=O)(=O)c2ccc(C(=O)[O-])cc2)ncc2ccncc12
# ORCA input file 'CHEMBL3687330.inp' generated successfully with charge -1 and multiplicity 1.
# Processing CHEMBL3687345: Cc1c(N(Cc2ccc3c(c2)CCC3(O)C(F)(F)F)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3687345.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687349: Cc1c(N(Cc2ccc(C(O)(C3CC3)C(F)(F)F)cc2)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3687349.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682557: O=C([O-])c1ccc(S(=O)(=O)N(Cc2ccc(OC(F)(F)F)cc2)c2ncc3ccccc3c2Cl)cc1
# ORCA input file 'CHEMBL3682557.inp' generated successfully with charge -1 and multiplicity 1.
# Processing CHEMBL3682560: Cc1c(N(Cc2ccc(OCC3CCC3)cc2)S(=O)(=O)c2ccc(C(=O)[O-])cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3682560.inp' generated successfully with charge -1 and multiplicity 1.
# Processing CHEMBL4246499: O=C(N[C@@H](Cc1ccccc1)c1ncccc1C(F)(F)F)c1ccc2cccnc2c1
# ORCA input file 'CHEMBL4246499.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3299024: FC(F)(F)Oc1cc2[nH]ncc2cc1-c1ccccc1C(F)(F)F
# ORCA input file 'CHEMBL3299024.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4247847: C[C@H](NC(=O)N[C@@H](c1ccc(C(F)(F)F)cc1)c1ncccc1F)C(F)(F)F
# ORCA input file 'CHEMBL4247847.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3911625: Cn1c(=O)c2c(CC(=O)Nc3nc(-c4cc(Cl)ccc4F)cs3)cccc2n(C)c1=O
# ORCA input file 'CHEMBL3911625.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3920559: Cn1c(=O)c2c(CC(=O)Nc3nc(-c4cccc(OC(F)(F)F)c4)cs3)cccc2n(C)c1=O
# ORCA input file 'CHEMBL3920559.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3918948: CC(C)c1sc2c(c1CC(=O)Nc1nc(-c3ccc(C(F)(F)F)c(F)c3)cs1)c(=O)n(C)c(=O)n2C
# ORCA input file 'CHEMBL3918948.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3896353: CCc1sc2c(c1CC(=O)Nc1nc(-c3cc(F)c(OCC(F)(F)F)c(F)c3)cs1)c(=O)n(C)c(=O)n2C
# ORCA input file 'CHEMBL3896353.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3947821: Cn1c(=O)c2c(CC(=O)Nc3nc(-c4cc(F)cc(C(F)(F)F)c4)cs3)coc2n(C)c1=O
# ORCA input file 'CHEMBL3947821.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687321: Cc1c(N(Cc2ccc(OC(F)(F)F)cc2)S(=O)(=O)c2ccc(C(=O)[O-])cc2)ncc2ccn(C)c12
# ORCA input file 'CHEMBL3687321.inp' generated successfully with charge -1 and multiplicity 1.
# Processing CHEMBL3687335: Cc1c(N(Cc2cnc3ccccc3c2)S(=O)(=O)c2ccc(C(=O)[O-])cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3687335.inp' generated successfully with charge -1 and multiplicity 1.
# Processing CHEMBL3687352: Cc1cc2ccccc2nc1N(Cc1ccc2c(c1)CCCC2)S(=O)(=O)c1ccc(C(=O)O)cc1
# ORCA input file 'CHEMBL3687352.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687374: Cc1c(N(Cc2ccc(C(F)(F)C3CC3)c(F)c2)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3687374.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3951379: Cn1c(=O)c2c(CC(=O)Nc3nc(-c4ccc(F)c(Cl)c4)cs3)cccc2n(C)c1=O
# ORCA input file 'CHEMBL3951379.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL1289835: Cc1[nH]c2ccc(OCc3ccccc3)cc2c1CCN
# ORCA input file 'CHEMBL1289835.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL357130: CN(C)CCc1c[nH]c2ccc(OCc3ccccc3)cc12
# ORCA input file 'CHEMBL357130.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3980601: COC(=O)[C@@H](c1ccccc1)N(Cc1cccc(OC)c1)C(=O)c1ccccc1
# ORCA input file 'CHEMBL3980601.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3889714: COc1cccc([C@H](C)N(C(=O)c2ccccc2)[C@@H](C(N)=O)c2ccccc2)c1
# ORCA input file 'CHEMBL3889714.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3926675: CC[C@H](c1ccccc1)N(C(=O)c1ccccc1)[C@@H](C(N)=O)c1ccccc1
# ORCA input file 'CHEMBL3926675.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3299019: COc1cc2[nH]ncc2cc1-c1ccccc1C(F)(F)F
# ORCA input file 'CHEMBL3299019.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3577885: C[C@H](c1ccc(F)cc1)N(Cc1cccc(C(=O)O)c1)C(=O)c1cnc2ccccc2c1
# ORCA input file 'CHEMBL3577885.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4647464: COC(=O)CC[C@H]1N[C@H](C(=O)NCc2ccc(F)cc2)Cc2c1[nH]c1ccccc21
# ORCA input file 'CHEMBL4647464.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL1288717: NCCc1c[nH]c2ccc(Br)cc12
# ORCA input file 'CHEMBL1288717.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4246904: O=C(N[C@@H](c1ccc(C(F)(F)F)c(F)c1)c1ncccc1C(F)(F)F)c1ccc2cccnc2c1
# ORCA input file 'CHEMBL4246904.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687392: COC(c1ccc(CN(c2ncc3ccccc3c2C)S(=O)(=O)c2ccc(C(=O)O)cc2)cc1)(C(F)(F)F)C(F)(F)F
# ORCA input file 'CHEMBL3687392.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687397: Cc1c(N(Cc2ccc(OC(F)(F)F)cc2)S(=O)(=O)c2ccc(C(=O)O)cc2)nc(C2CCCC2)c2ccccc12
# ORCA input file 'CHEMBL3687397.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL122413: COc1cccc(NC(=O)/C=C/c2ccc(Cl)cc2)c1
# ORCA input file 'CHEMBL122413.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3235963: N#Cc1ccc(NC(=O)N2CCc3ccccc3[C@H]2c2ccc(C(F)(F)F)cc2)cc1
# ORCA input file 'CHEMBL3235963.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3235973: O=C(Nc1ccc(F)cc1)N1CCc2ncccc2[C@H]1c1ccc(C(F)(F)F)cc1
# ORCA input file 'CHEMBL3235973.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4752955: NC(=O)[C@@H](c1ccccc1)N(C(=O)c1cccnc1)[C@@H]1CCc2c(F)cc(F)cc21
# ORCA input file 'CHEMBL4752955.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3941901: Cn1c(=O)c2c(CC(=O)Nc3nc(-c4ccc(F)c(C(F)(F)F)c4F)cs3)nsc2n(C)c1=O
# ORCA input file 'CHEMBL3941901.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4247395: O=C(N[C@@H](c1ccc(C(F)(F)F)c(F)c1)c1ncccc1C(F)(F)F)c1ccccc1
# ORCA input file 'CHEMBL4247395.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4245344: O=C(N[C@@H](c1ccc(C(F)(F)F)cc1)c1cnccc1C(F)(F)F)c1ccc2cccnc2c1
# ORCA input file 'CHEMBL4245344.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3353595: O=C(O)c1ccc(S(=O)(=O)N(Cc2ccccc2OC(F)(F)F)c2ncc(C(F)(F)F)cc2Cl)cc1
# ORCA input file 'CHEMBL3353595.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3353596: O=C(O)c1ccc(S(=O)(=O)N(Cc2cccc(OC(F)(F)F)c2)c2ncc(C(F)(F)F)cc2Cl)cc1
# ORCA input file 'CHEMBL3353596.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3353590: O=C(O)c1ccc(S(=O)(=O)N(CC2CCCCC2)c2ncc(C(F)(F)F)cc2Cl)cc1
# ORCA input file 'CHEMBL3353590.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL2324349: Cc1c(N(Cc2ccc(F)c(C(F)(F)F)c2)S(=O)(=O)c2ccc(C(=O)O)cc2)sc2ccccc12
# ORCA input file 'CHEMBL2324349.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4238688: COc1ccc([C@H](NC(=O)c2ccc3cccnc3c2)c2ncccc2C(F)(F)F)cc1
# ORCA input file 'CHEMBL4238688.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3353591: O=C(O)c1ccc(S(=O)(=O)N(CCN2CCOCC2)c2ncc(C(F)(F)F)cc2Cl)cc1
# ORCA input file 'CHEMBL3353591.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3353599: O=C(O)c1ccc(S(=O)(=O)N(Cc2ccc(F)c(C(F)(F)F)c2)c2ncc(C(F)(F)F)cc2Cl)cc1
# ORCA input file 'CHEMBL3353599.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682544: Cc1c(N(Cc2ccc(F)c(C(F)(F)F)n2)S(=O)(=O)c2ccc(C(=O)[O-])cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3682544.inp' generated successfully with charge -1 and multiplicity 1.
# Processing CHEMBL3682553: Cc1c(N(Cc2ccc(F)c(C(F)(F)F)c2)S(=O)(=O)c2ccc(C(=O)[O-])cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3682553.inp' generated successfully with charge -1 and multiplicity 1.
# Processing CHEMBL3682580: Cc1c(N(Cc2ccc(-c3ccccc3F)cc2)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3682580.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682552: Cc1c(N(Cc2ccc(Oc3ccccc3)cc2)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3682552.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682569: Cc1c(N(Cc2ccc3c(c2)CC(C)(C)C3)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3682569.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682575: Cc1c(N(Cc2ccc3c(c2)CC(C)(C)O3)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3682575.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682582: Cc1nc(N(Cc2ccc(OC(F)(F)F)cc2)S(=O)(=O)c2ccc(C(=O)[O-])cc2)c(C)c2ccccc12
# ORCA input file 'CHEMBL3682582.inp' generated successfully with charge -1 and multiplicity 1.
# Processing CHEMBL3687343: Cc1c(N(Cc2ccc(CC3CC3)cc2F)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3687343.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687346: Cc1c(N(Cc2ccc(C(C)(O)C(F)(F)C(F)(F)F)cc2)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3687346.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687356: O=C(O)c1ccc(S(=O)(=O)N(Cc2cc3c(F)cc(F)cc3s2)c2ncc3ccccc3c2C2CC2)cc1
# ORCA input file 'CHEMBL3687356.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687372: Cc1c(N(Cc2ccc(C(F)(F)C3CC3)c(Cl)c2)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3687372.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687376: Cc1c(N(Cc2cccc(C(F)(F)C3CC3)c2)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3687376.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687386: Cc1c(N(Cc2ccc(OC(F)(F)F)cc2)S(=O)(=O)c2ccc(C(=O)O)cc2)nc(C2CC2)c2c(C)cccc12
# ORCA input file 'CHEMBL3687386.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687319: Cc1cc2cc(F)ccc2nc1N(Cc1ccc(OC(F)(F)F)cc1)S(=O)(=O)c1ccc(C(=O)O)cc1
# ORCA input file 'CHEMBL3687319.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687323: COc1c(N(Cc2ccc(OC(F)(F)F)cc2)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3687323.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3944579: Cc1oc2c(c1CC(=O)Nc1nc(-c3cccc(C(F)(F)F)c3F)cs1)c(=O)n(C)c(=O)n2C
# ORCA input file 'CHEMBL3944579.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3948210: Cn1c(=O)c2c(CC(=O)Nc3nc(-c4cc(F)c(OCC(F)(F)F)c(F)c4)cs3)ccnc2n(C)c1=O
# ORCA input file 'CHEMBL3948210.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4248426: O=C(N[C@@H](c1ccc(C(F)(F)F)cc1)c1ncccc1C(F)(F)F)c1ccc2ncccc2c1
# ORCA input file 'CHEMBL4248426.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL1288716: NCCc1c[nH]c2ccc(Cl)cc12
# ORCA input file 'CHEMBL1288716.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687406: O=C([O-])c1ccc(S(=O)(=O)N(Cc2ccc(C(F)(F)C3CC3)c(F)c2)c2ncc3ccccc3c2C(F)(F)F)cc1
# ORCA input file 'CHEMBL3687406.inp' generated successfully with charge -1 and multiplicity 1.
# Processing CHEMBL3687408: Cc1c(N(Cc2ccc3c(c2)c(Cl)cn3C)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3687408.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3577897: O=C(O)c1cccc(CN(C(=O)c2cnc3ccccc3c2)[C@H](CO)c2ccccc2)c1
# ORCA input file 'CHEMBL3577897.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3577886: C[C@H](c1ccc(F)cc1)N(Cc1cccc(C(=O)O)c1)C(=O)c1cc2ccccc2nn1
# ORCA input file 'CHEMBL3577886.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3577880: C[C@H](c1ccc(F)cc1)N(Cc1cccc(C(=O)O)c1)C(=O)c1cccc(-c2ccccc2)c1
# ORCA input file 'CHEMBL3577880.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4750971: Cc1ncccc1C(=O)N([C@@H]1CCc2c(F)cc(Cl)cc21)[C@@H](C(N)=O)c1ccccc1
# ORCA input file 'CHEMBL4750971.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3968269: CCc1ccc(-c2csc(NC(=O)Cc3cccc4c3c(=O)n(C)c(=O)n4C)n2)cc1
# ORCA input file 'CHEMBL3968269.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3577903: CC[C@H](c1ccc(C)o1)N(Cc1cccc(C(=O)O)c1)C(=O)c1cnc2ccccc2c1
# ORCA input file 'CHEMBL3577903.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3577902: C[C@H](c1cccc(Cl)c1)N(Cc1cccc(C(=O)O)c1)C(=O)c1cnc2ccccc2c1
# ORCA input file 'CHEMBL3577902.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3577896: O=C(O)c1cccc(CN(Cc2ccc(F)cc2)C(=O)c2cnc3ccccc3c2)c1
# ORCA input file 'CHEMBL3577896.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3577892: Cc1ccc(CN(C(=O)c2cnc3ccccc3c2)[C@H](C)c2ccc(F)cc2)cc1C(=O)O
# ORCA input file 'CHEMBL3577892.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3577891: C[C@H](c1ccc(F)cc1)N(Cc1ccc(F)c(C(=O)O)c1)C(=O)c1cnc2ccccc2c1
# ORCA input file 'CHEMBL3577891.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3577888: CC(c1ccc(F)cc1)N(Cc1cccc(C(=O)O)c1)C(=O)C1Cc2ccccc2C1
# ORCA input file 'CHEMBL3577888.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3576881: C[C@H](c1ccc(F)cc1)N(Cc1cccc(C(=O)O)c1)C(=O)c1cn2ccccc2n1
# ORCA input file 'CHEMBL3576881.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3235968: CC(C)NC(=O)N1CCc2ccccc2[C@H]1c1ccc(C(F)(F)F)cc1
# ORCA input file 'CHEMBL3235968.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3235971: O=C(NC(c1ccccc1)C(F)(F)F)N1CCc2ccccc2[C@H]1c1ccc(C(F)(F)F)cc1
# ORCA input file 'CHEMBL3235971.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3235972: O=C(Nc1ccc(F)cc1)N1CC(F)(F)c2ccccc2C1c1ccc(C(F)(F)F)cc1
# ORCA input file 'CHEMBL3235972.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3353601: CC(C)(c1ccc(CN(c2ncc(C(F)(F)F)cc2Cl)S(=O)(=O)c2ccc(C(=O)O)cc2)cc1)C(F)(F)F
# ORCA input file 'CHEMBL3353601.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687403: O=C(O)c1ccc(S(=O)(=O)N(Cc2ccc(OC(F)(F)F)cc2)c2nc(C3CC3)c3ccccc3c2C2CC2)cc1
# ORCA input file 'CHEMBL3687403.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3898642: C[C@H](c1cccc(Cl)c1)N(C(=O)c1ccccc1)[C@@H](C(N)=O)c1ccccc1
# ORCA input file 'CHEMBL3898642.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687360: Cc1c(N(Cc2ccc(C(F)(F)C3CCC3)cc2)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3687360.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4237618: O=C(N[C@@H](c1ccc(C(F)(F)F)c(F)c1)c1ncccc1F)c1ccc(=O)[nH]c1
# ORCA input file 'CHEMBL4237618.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL2442014: CCN(C(=O)c1ccccc1OCc1ccc(Cl)cc1)[C@H]1CCC[C@@H](N)C1
# ORCA input file 'CHEMBL2442014.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL2442013: CCN(C(=O)c1ccccc1OCc1ccc(Cl)cc1)[C@@H]1CCC[C@H](N)C1
# ORCA input file 'CHEMBL2442013.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL2442021: CCN(C(=O)c1ccccc1OCc1ccccc1C)[C@@H]1CCC[C@H](N)C1
# ORCA input file 'CHEMBL2442021.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL2442033: N[C@H]1CCC[C@@H](N(C(=O)c2ccccc2OCc2ccccc2)C2CCC2)C1
# ORCA input file 'CHEMBL2442033.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL1955989: FC(F)(F)c1ccccc1-c1ccc2[nH]c(/C=C/C3CCCCC3)nc2c1
# ORCA input file 'CHEMBL1955989.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL2443060: O=C(Nc1ccc(OC(F)(F)F)cc1)N1CCC2(CC1)C[C@H](O)c1cccc(Cl)c1O2
# ORCA input file 'CHEMBL2443060.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL2443070: O=C1CC2(CCN(C(=O)Nc3ccc(OC(F)(F)F)cc3)CC2)Oc2c(Cl)cccc21
# ORCA input file 'CHEMBL2443070.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687410: Cc1c(N(Cc2ccc(OC(F)(F)F)cc2)S(=O)(=O)c2ccc(C(=O)NC#N)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3687410.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3935137: Cn1c(=O)c2c(CC(=O)Nc3nc(-c4ccc(C(F)(F)F)c(F)c4)cs3)cccc2n(C)c1=O
# ORCA input file 'CHEMBL3935137.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3235977: O=C(Nc1ccc(F)cc1)N1CCc2cncnc2C1c1ccc(C(F)(F)F)cc1
# ORCA input file 'CHEMBL3235977.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3235966: O=C(Nc1ccncc1)N1CCc2ccccc2[C@H]1c1ccc(C(F)(F)F)cc1
# ORCA input file 'CHEMBL3235966.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3235969: C[C@H](NC(=O)N1CCc2ccccc2[C@H]1c1ccc(C(F)(F)F)cc1)C(F)(F)F
# ORCA input file 'CHEMBL3235969.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3235974: O=C(Nc1ccc(F)cc1)N1CCc2cnccc2C1c1ccc(C(F)(F)F)cc1
# ORCA input file 'CHEMBL3235974.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3974529: Cc1c(N(Cc2ccc(OC(F)(F)F)cc2)S(=O)(=O)c2ccc(C(=O)O)cc2)sc2ccccc12
# ORCA input file 'CHEMBL3974529.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3892970: Cn1c(=O)c2c(CC(=O)Nc3nc(-c4ccc(OC(F)(F)F)c(F)c4)cs3)nsc2n(C)c1=O
# ORCA input file 'CHEMBL3892970.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687354: Cc1cc2ccccc2nc1N(Cc1ccc(C(F)(F)C2CC2)cc1)S(=O)(=O)c1ccc(C(=O)O)cc1
# ORCA input file 'CHEMBL3687354.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687370: Cc1c(N(Cc2cc3cccc(Cl)c3s2)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3687370.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687382: Cn1ccc2c(N(Cc3ccc(OC(F)(F)F)cc3)S(=O)(=O)c3ccc(C(=O)O)cc3)ncc(Cl)c21
# ORCA input file 'CHEMBL3687382.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687394: COC1(C(F)(F)F)CCc2cc(CN(c3ncc4ccccc4c3C)S(=O)(=O)c3ccc(C(=O)O)cc3)ccc21
# ORCA input file 'CHEMBL3687394.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687413: NC(=O)c1ccc(S(=O)(=O)N(Cc2ccc(OC(F)(F)F)cc2)c2ncc3ccccc3c2C(F)(F)F)cc1
# ORCA input file 'CHEMBL3687413.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3920106: Cc1oc2c(c1CC(=O)Nc1nc(-c3ccc(C(F)(F)F)cc3F)cs1)c(=O)n(C)c(=O)n2C
# ORCA input file 'CHEMBL3920106.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682558: Cc1c(N(Cc2ccc(C3CC3)cc2)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3682558.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682565: Cc1c(N(Cc2ccc(OCC3CC3)c(Cl)c2)S(=O)(=O)c2ccc(C(=O)[O-])cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3682565.inp' generated successfully with charge -1 and multiplicity 1.
# Processing CHEMBL3682568: Cc1c(N(Cc2ccc3c(c2)CCC3(C)C)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3682568.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682591: Cc1c(N(Cc2ccc(OC(F)(F)F)cc2)S(=O)(=O)c2ccc(C(=O)O)cc2)nc(C(F)(F)F)c2ccccc12
# ORCA input file 'CHEMBL3682591.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682608: Cc1ccc2c(C)c(N(Cc3ccc(OC(F)(F)F)cc3)S(=O)(=O)c3ccc(C(=O)O)cc3)ncc2c1
# ORCA input file 'CHEMBL3682608.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682615: Cc1cc2c(Cl)cccc2nc1N(Cc1ccc(OC(F)(F)F)cc1)S(=O)(=O)c1ccc(C(=O)[O-])cc1
# ORCA input file 'CHEMBL3682615.inp' generated successfully with charge -1 and multiplicity 1.
# Processing CHEMBL3682619: Cc1cc2ccccc2nc1N(Cc1cccc(OC(F)(F)F)c1)S(=O)(=O)c1ccc(C(=O)[O-])cc1
# ORCA input file 'CHEMBL3682619.inp' generated successfully with charge -1 and multiplicity 1.
# Processing CHEMBL3687320: Cc1cc2ccc(F)cc2nc1N(Cc1ccc(OC(F)(F)F)cc1)S(=O)(=O)c1ccc(C(=O)O)cc1
# ORCA input file 'CHEMBL3687320.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687322: O=C(O)c1ccc(S(=O)(=O)N(Cc2ccc(OC(F)(F)F)cc2)c2cc3c(Cl)cccc3c(Br)n2)cc1
# ORCA input file 'CHEMBL3687322.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687326: CC(=O)c1ccc(S(=O)(=O)N(Cc2ccc(OC(F)(F)F)cc2)c2ncc3ccccc3c2C)cc1
# ORCA input file 'CHEMBL3687326.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687327: O=C(O)c1ccc(S(=O)(=O)N(Cc2ccc(OC(F)(F)F)cc2)c2ncc3ccccc3c2Br)cc1
# ORCA input file 'CHEMBL3687327.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687328: CCc1c(N(Cc2ccc(OC(F)(F)F)cc2)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3687328.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687331: Cc1c(N(Cc2cc3ccccc3n2C)S(=O)(=O)c2ccc(C(=O)[O-])cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3687331.inp' generated successfully with charge -1 and multiplicity 1.
# Processing CHEMBL3687334: CCn1c(CN(c2ncc3ccccc3c2C)S(=O)(=O)c2ccc(C(=O)[O-])cc2)cc2ccc(Cl)cc21
# ORCA input file 'CHEMBL3687334.inp' generated successfully with charge -1 and multiplicity 1.
# Processing CHEMBL3687341: Cc1c(N(Cc2ccc(C(C)(O)C(F)(F)F)c(F)c2)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3687341.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687351: Cc1c(N(C2CCc3cc(OC(F)(F)F)ccc32)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3687351.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687357: O=C([O-])c1ccc(S(=O)(=O)N(Cc2ccc(C(F)(F)C3CC3)c(Cl)c2)c2ncc3ccccc3c2C2CC2)cc1
# ORCA input file 'CHEMBL3687357.inp' generated successfully with charge -1 and multiplicity 1.
# Processing CHEMBL3687395: COC(C)(c1ccc(CN(c2ncc3ccccc3c2C)S(=O)(=O)c2ccc(C(=O)O)cc2)cc1)C(F)(F)C(F)(F)F
# ORCA input file 'CHEMBL3687395.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687405: O=C([O-])c1ccc(S(=O)(=O)N(Cc2cc3c(F)cc(F)cc3s2)c2ncc3ccccc3c2C(F)(F)F)cc1
# ORCA input file 'CHEMBL3687405.inp' generated successfully with charge -1 and multiplicity 1.
# Processing CHEMBL3577906: C[C@H](c1ccc(F)cc1F)N(Cc1cccc(C(=O)O)c1)C(=O)c1cc2ccccn2n1
# ORCA input file 'CHEMBL3577906.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3965541: Cn1c(=O)c2c(CC(=O)Nc3nc(-c4cccc(Cl)c4)cs3)cccc2n(C)c1=O
# ORCA input file 'CHEMBL3965541.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687336: Cc1c(N(Cc2ncc(CC3CC3)cn2)S(=O)(=O)c2ccc(C(=O)[O-])cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3687336.inp' generated successfully with charge -1 and multiplicity 1.
# Processing CHEMBL3687347: Cc1c(N(Cc2cc(F)c3c(c2)CCC3)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3687347.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4237740: C[C@H](NC(=O)N[C@@H](c1ccc(C(F)(F)F)cc1)c1ncccc1C(F)(F)F)C(F)(F)F
# ORCA input file 'CHEMBL4237740.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3899728: NC(=O)[C@@H](c1ccccc1)N(Cc1cccc(C(F)(F)F)c1)C(=O)c1ccccc1
# ORCA input file 'CHEMBL3899728.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3917717: COc1cccc([C@@H](C)N(C(=O)c2ccccc2)[C@@H](C(N)=O)c2ccccc2)c1
# ORCA input file 'CHEMBL3917717.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3943602: COc1cccc(CN(C(=O)c2cccs2)[C@@H](C(N)=O)c2ccccc2)c1
# ORCA input file 'CHEMBL3943602.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3952818: COc1cccc(CN(C(=O)c2ccccc2)[C@H](C)C(N)=O)c1
# ORCA input file 'CHEMBL3952818.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4446849: O=C(/C=C/c1ccc(C(F)(F)F)cc1)Nc1ccccc1C(=O)O
# ORCA input file 'CHEMBL4446849.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4454519: O=C(/C=C/c1ccc(Br)cc1)Nc1ccccc1C(=O)O
# ORCA input file 'CHEMBL4454519.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL1086310: CC(C)c1ccc(NC(=O)Cn2cnc3c2c(=O)n(C)c(=O)n3C)cc1
# ORCA input file 'CHEMBL1086310.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4533807: C/C=C(\C)[C@H]1C(C)=C[C@H]2C[C@@H](C)C[C@H]3C(=O)/C(=C\NCCO)C(=O)[C@]1(C)[C@H]23
# ORCA input file 'CHEMBL4533807.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4249999: O=C(N[C@@H](c1ccc(C(F)(F)F)cc1)c1ncccc1C(F)(F)F)c1cccnc1
# ORCA input file 'CHEMBL4249999.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4247268: N#Cc1ccc(C(=O)N[C@@H](c2ccc(C(F)(F)F)cc2)c2ncccc2C(F)(F)F)cc1
# ORCA input file 'CHEMBL4247268.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL2443065: O=C(Nc1nc(C(F)(F)F)cs1)N1CCC2(CCc3cccc(Cl)c3O2)CC1
# ORCA input file 'CHEMBL2443065.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3973096: COc1cc(CN(CC(N)=O)C(=O)c2cccs2)ccc1OCc1ccc(F)cc1
# ORCA input file 'CHEMBL3973096.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4073922: O=C(NC1(c2ccccc2)CC1)c1c(CN2CCC(N3CCCCC3)CC2)c(-c2cccc(C(F)(F)F)c2)nc2cc(Br)ccc12
# ORCA input file 'CHEMBL4073922.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3914798: Cn1c(=O)c2c(cnn2CC(=O)Nc2nc(-c3cc(Cl)c(OCC(C)(C)C)c(Cl)c3)cs2)n(C)c1=O
# ORCA input file 'CHEMBL3914798.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4517528: O=C(/C=C/c1ccccc1Cl)Nc1ccccc1C(=O)O
# ORCA input file 'CHEMBL4517528.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL2443075: O=C(Nc1ccc(OC(F)(F)F)cc1)N1CCC2(CC1)CC(O)c1cccc(F)c1O2
# ORCA input file 'CHEMBL2443075.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL2443074: O=C(Nc1ccc(C(F)(F)F)cc1)N1CCC2(CC1)CC(O)c1cccc(Br)c1O2
# ORCA input file 'CHEMBL2443074.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL2443086: O=C(Nc1ccc(OC(F)(F)F)cc1)N1CCC2(CCc3cccc(Cl)c3O2)CC1
# ORCA input file 'CHEMBL2443086.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL2443085: O=C(Nc1ccc(C(F)(F)F)cc1)N1CCC2(CCc3cccc(Br)c3O2)CC1
# ORCA input file 'CHEMBL2443085.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL2442037: CCCN(C(=O)c1ccccc1OCc1ccccc1)[C@@H]1CCC[C@H](N)C1
# ORCA input file 'CHEMBL2442037.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3235965: O=C(Nc1cccnc1)N1CCc2ccccc2[C@H]1c1ccc(C(F)(F)F)cc1
# ORCA input file 'CHEMBL3235965.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL2032210: O=C(Nc1ccc(F)cc1)N1CCc2ccccc2[C@H]1c1ccc(C(F)(F)F)cc1
# ORCA input file 'CHEMBL2032210.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3235980: N#Cc1ccc(NC(=O)N2CCc3cccnc3[C@H]2c2ccc(C(F)(F)F)cc2)cc1
# ORCA input file 'CHEMBL3235980.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3235982: C[C@H](NC(=O)N1CCc2ccccc2[C@H]1c1ccc(C(F)(F)F)nc1)C(F)(F)F
# ORCA input file 'CHEMBL3235982.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3235984: C[C@H](NC(=O)N1CCc2cccnc2[C@H]1c1ccc(C(F)(F)F)c(F)c1)C(F)(F)F
# ORCA input file 'CHEMBL3235984.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL2442015: CCN(C(=O)c1ccccc1OCc1cccc(Cl)c1)C1CCCC(N)C1
# ORCA input file 'CHEMBL2442015.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4647444: COC(=O)[C@@H]1Cc2c([nH]c3ccccc23)[C@@H](c2ccccc2)N1Cc1ccccc1
# ORCA input file 'CHEMBL4647444.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3235964: O=C(Nc1ccccn1)N1CCc2ccccc2[C@H]1c1ccc(C(F)(F)F)cc1
# ORCA input file 'CHEMBL3235964.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3235961: N#Cc1ccccc1NC(=O)N1CCc2ccccc2[C@H]1c1ccc(C(F)(F)F)cc1
# ORCA input file 'CHEMBL3235961.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3235979: O=C(Nc1cccnc1)N1CCc2cccnc2[C@H]1c1ccc(C(F)(F)F)cc1
# ORCA input file 'CHEMBL3235979.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682559: Cc1c(N(Cc2ccc(OCC3CC3)cc2)S(=O)(=O)c2ccc(C(=O)[O-])cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3682559.inp' generated successfully with charge -1 and multiplicity 1.
# Processing CHEMBL3682599: Cc1c(N(Cc2ccc3c(Cl)cn(C)c3c2)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3682599.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL2443078: O=C(Nc1ccc(OC(F)(F)F)cc1)N1CCC2(CC1)C[C@H](O)c1cccc(F)c1O2
# ORCA input file 'CHEMBL2443078.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL2443084: O=C(Nc1ccc(C(F)(F)F)cc1)N1CCC2(CCc3cccc(Cl)c3O2)CC1
# ORCA input file 'CHEMBL2443084.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3235976: O=C(Nc1ccc(F)cc1)N1CCc2cccnc2[C@H]1c1ccc(C(F)(F)F)cc1
# ORCA input file 'CHEMBL3235976.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3353572: O=C(O)c1ccc(S(=O)(=O)N(Cc2ccccc2)c2ncc(C(F)(F)F)cc2Cl)cc1
# ORCA input file 'CHEMBL3353572.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3353588: O=C(O)c1ccc(S(=O)(=O)N(CCc2ccccc2)c2ncc(C(F)(F)F)cc2Cl)cc1
# ORCA input file 'CHEMBL3353588.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3353598: O=C(O)c1ccc(S(=O)(=O)N(Cc2ccc(F)cc2)c2ncc(C(F)(F)F)cc2Cl)cc1
# ORCA input file 'CHEMBL3353598.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3353603: N#CC1(c2ccc(CN(c3ncc(C(F)(F)F)cc3Cl)S(=O)(=O)c3ccc(C(=O)O)cc3)cc2)CC1
# ORCA input file 'CHEMBL3353603.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682548: Cc1c(N(Cc2ccccc2)S(=O)(=O)c2ccc(C(=O)[O-])cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3682548.inp' generated successfully with charge -1 and multiplicity 1.
# Processing CHEMBL3682550: Cc1c(N(Cc2ccc(CC3CC3)cc2)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3682550.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687384: Cc1c(N(Cc2ccc(OC(F)(F)F)cc2)S(=O)(=O)c2ccc(C(=O)O)cc2)nc(-c2cccnc2)c2ccccc12
# ORCA input file 'CHEMBL3687384.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687393: COC(C)(c1ccc(CN(c2ncc3ccccc3c2C)S(=O)(=O)c2ccc(C(=O)O)cc2)cc1Cl)C(F)(F)F
# ORCA input file 'CHEMBL3687393.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687396: Cc1c(N(Cc2ccc(OC(F)(F)F)cc2)S(=O)(=O)c2ccc(C(=O)O)cc2)nc(C(C)C)c2ccccc12
# ORCA input file 'CHEMBL3687396.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL8165: COc1ccc2[nH]cc(CCN)c2c1
# ORCA input file 'CHEMBL8165.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL460302: NCCc1c[nH]c2c(OCc3ccccc3)cccc12
# ORCA input file 'CHEMBL460302.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4164465: N#Cc1ccc(O[C@H]2CN(S(=O)(=O)c3ccc(Cl)cc3Cl)C[C@@]2(O)CO)cc1F
# ORCA input file 'CHEMBL4164465.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL1173240: Cc1nc(Nc2cccc3c2C[C@H](O)CC3)oc1-c1ccc(C(F)(F)F)cc1
# ...
# ORCA input file 'CHEMBL3947368.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3956363: Cc1sc2c(c1CC(=O)Nc1nc(-c3ccc(Cl)c(Cl)c3)cs1)c(=O)n(C)c(=O)n2C
# ORCA input file 'CHEMBL3956363.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3981050: Cn1c(=O)c2c(CC(=O)Nc3nc(-c4cc(F)c(CCC(F)(F)F)c(F)c4)cs3)coc2n(C)c1=O
# ORCA input file 'CHEMBL3981050.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3929233: Cn1c(=O)c2c(CC(=O)Nc3nc(-c4cc(F)c(OCC(F)(F)F)c(Cl)c4)cs3)coc2n(C)c1=O
# ORCA input file 'CHEMBL3929233.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3948438: Cn1c(=O)c2c(CC(=O)Nc3nc(-c4ccc(I)cc4)cs3)cccc2n(C)c1=O
# ORCA input file 'CHEMBL3948438.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4208555: O=C(NC[C@@H](Cc1ccccc1)N1CCC(O)(C(F)(F)F)CC1)C1(c2ccc(Cl)cc2)CCCC1
# ORCA input file 'CHEMBL4208555.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3353587: O=C(O)c1ccc(S(=O)(=O)N(Cc2ccccc2)c2ncc(Cl)cc2C(F)(F)F)cc1
# ORCA input file 'CHEMBL3353587.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3353608: O=C(O)c1ccc(S(=O)(=O)N(Cc2ccc(F)c(C(F)(F)F)c2)c2ncc(Cl)cc2Cl)cc1
# ORCA input file 'CHEMBL3353608.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4786793: C[C@H](c1ccccc1)N(C(=O)c1ccccc1)[C@@H](C(N)=O)c1ccccc1
# ORCA input file 'CHEMBL4786793.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5287269: CCn1nnc(-c2sc(-c3cccc(N(C)C)c3)nc2O)n1
# ORCA input file 'CHEMBL5287269.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5269673: CCC(=O)c1sc(-c2cccc(F)c2)nc1O
# ORCA input file 'CHEMBL5269673.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4550460: C/C=C(\C)[C@H]1C(C)=C[C@H]2C[C@@H](C)C[C@@H](C(=O)O)[C@@H]2[C@@]1(C)C(=O)CCO
# ORCA input file 'CHEMBL4550460.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL104: Clc1ccccc1C(c1ccccc1)(c1ccccc1)n1ccnc1
# ORCA input file 'CHEMBL104.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5272167: CCn1/c(=N/S(=O)(=O)c2ccccc2)n(Cc2ccc(C(F)(F)F)c(F)c2)c2cc(C(F)(F)F)ccc21
# ORCA input file 'CHEMBL5272167.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3953065: Cn1c(=O)c2c(CC(=O)Nc3nc(-c4ccc(Cl)c(Cl)c4)cs3)cccc2n(C)c1=O
# ORCA input file 'CHEMBL3953065.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3904928: Cc1oc2c(c1CC(=O)Nc1nc(-c3ccc(OC(F)(F)F)c(F)c3)cs1)c(=O)n(C)c(=O)n2C
# ORCA input file 'CHEMBL3904928.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5275700: CCn1nnc(-c2sc(-c3ccc(Cl)cc3)nc2O)n1
# ORCA input file 'CHEMBL5275700.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4751372: C[C@H](c1cc(F)cc(F)c1F)N(C(=O)c1ccccc1)[C@@H](C(N)=O)c1ccccc1
# ORCA input file 'CHEMBL4751372.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4759917: NC(=O)[C@@H](c1ccccc1)N(C(=O)c1ccccc1)[C@@H]1CCc2ccc(F)cc21
# ORCA input file 'CHEMBL4759917.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4785621: COc1ncccc1C(=O)N([C@@H]1CCc2c(F)cc(Cl)cc21)[C@@H](C(N)=O)c1ccccc1
# ORCA input file 'CHEMBL4785621.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL294199: COc1cc(CNC(=O)CCCC/C=C/C(C)C)ccc1O
# ORCA input file 'CHEMBL294199.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5267089: COc1cc(CN(CCN)c2nc3ccccc3s2)ccc1OCc1ccccc1F
# ORCA input file 'CHEMBL5267089.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4587626: C[C@H](c1ccc(F)cc1)N(Cc1ccc(Cl)c(C(=O)O)c1)C(=O)c1cnc2ccccc2c1
# ORCA input file 'CHEMBL4587626.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682556: COc1nc(N(Cc2ccc(OC(F)(F)F)cc2)S(=O)(=O)c2ccc(C(=O)[O-])cc2)c(C)c2ccccc12
# ORCA input file 'CHEMBL3682556.inp' generated successfully with charge -1 and multiplicity 1.
# Processing CHEMBL3682578: Cc1c(N(Cc2cc3ccccc3s2)S(=O)(=O)c2ccc(C(=O)[O-])cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3682578.inp' generated successfully with charge -1 and multiplicity 1.
# Processing CHEMBL3682579: Cc1c(N(CC2CCN(c3ccccc3)CC2)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3682579.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682583: Cc1c(N(Cc2ccc(OC(F)(F)F)cc2)S(=O)(=O)c2ccc(C(=O)[O-])cc2)nc(-c2ccccc2)c2ccccc12
# ORCA input file 'CHEMBL3682583.inp' generated successfully with charge -1 and multiplicity 1.
# Processing CHEMBL3682602: Cc1c(N(Cc2ccc(OC(F)(F)F)cc2)S(=O)(=O)c2ccc(C(C)(C)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3682602.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687379: Cc1cc2ccccc2nc1N(Cc1ccc(F)c(C(F)(F)C2CC2)c1)S(=O)(=O)c1ccc(C(=O)O)cc1
# ORCA input file 'CHEMBL3687379.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682590: O=C(O)c1ccc(S(=O)(=O)N(Cc2ccc(OC(F)(F)F)cc2)c2ncc3ccccc3c2C(F)(F)F)cc1
# ORCA input file 'CHEMBL3682590.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682593: CC(=O)c1c(N(Cc2ccc(OC(F)(F)F)cc2)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3682593.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682594: CC(O)c1c(N(Cc2ccc(OC(F)(F)F)cc2)S(=O)(=O)c2ccc(C(=O)O)cc2)ncc2ccccc12
# ORCA input file 'CHEMBL3682594.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3682601: CONC(=O)c1ccc(S(=O)(=O)N(Cc2ccc(OC(F)(F)F)cc2)c2ncc3ccccc3c2C)cc1
# ORCA input file 'CHEMBL3682601.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687332: CCn1c(CN(c2ncc3ccccc3c2C)S(=O)(=O)c2ccc(C(=O)[O-])cc2)cc2ccccc21
# ORCA input file 'CHEMBL3687332.inp' generated successfully with charge -1 and multiplicity 1.
# Processing CHEMBL5284452: O=C(c1sc(-c2cccc(F)c2)nc1O)N1CCOCC1
# ORCA input file 'CHEMBL5284452.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4749804: NC(=O)[C@@H](c1ccccc1)N(C(=O)c1ccccc1)[C@@H]1CCc2c(F)cccc21
# ORCA input file 'CHEMBL4749804.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4791592: C[C@H](c1cc(F)cc(F)c1)N(C(=O)c1ccccc1O)[C@@H](C(N)=O)c1ccccc1
# ORCA input file 'CHEMBL4791592.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4758145: NC(=O)[C@@H](c1ccccc1)N(C(=O)c1ccccc1)[C@@H]1CCc2c(Cl)cccc21
# ORCA input file 'CHEMBL4758145.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4745090: NC(=O)[C@@H](c1ccccc1)N(C(=O)c1ccccc1)[C@@H]1CCCc2ccccc21
# ORCA input file 'CHEMBL4745090.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL422704: CCCCCc1cc(O)c2c(c1)OC(C)(CCC=C(C)C)C=C2
# ORCA input file 'CHEMBL422704.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL65312: CCOC(=O)c1sc(-c2ccccc2)nc1O
# ORCA input file 'CHEMBL65312.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5277486: CCOC(=O)c1sc(-c2ccccc2)nc1OC
# ORCA input file 'CHEMBL5277486.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5273671: CCOC(=O)c1sc(-c2cccc(Cl)c2)nc1O
# ORCA input file 'CHEMBL5273671.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5286159: CCOC(=O)c1oc(-c2ccc(Cl)cc2)nc1O
# ORCA input file 'CHEMBL5286159.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5280890: CCn1c(N(Cc2ccc(C(F)(F)F)cc2)S(=O)(=O)c2ccccc2)nc2cc(F)ccc21
# ORCA input file 'CHEMBL5280890.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL258502: COc1ccc(CCCOC(Cn2ccnc2)c2ccc(OC)cc2)cc1
# ORCA input file 'CHEMBL258502.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL465718: CCCCCc1cc2c(c(O)c1C(=O)O)[C@@H]1C=C(C)CC[C@H]1C(C)(C)O2
# ORCA input file 'CHEMBL465718.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5269402: C=C(C)[C@]12C[C@@H](C)[C@@]34OC(Cc5ccccc5)(O[C@@H]1C3C=C(COC(=O)Cc1ccc(O)c(OC)c1)C[C@]1(O)C(=O)C(C)=C[C@@H]41)O2
# ORCA input file 'CHEMBL5269402.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5275380: O=S(=O)(c1ccc(-c2nnn[nH]2)cc1)N(Cc1ccc(OC(F)(F)F)cc1)c1ncc2ccccc2c1C1CC1
# ORCA input file 'CHEMBL5275380.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4241349: O=C(O)c1ccc(C(=O)N[C@@H](c2ccc(OC(F)(F)F)c(F)c2)c2ncccc2F)nc1
# ORCA input file 'CHEMBL4241349.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4238340: O=C(N[C@@H](c1nccs1)c1ncccc1C(F)(F)F)c1ccc2cccnc2c1
# ORCA input file 'CHEMBL4238340.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL4245611: Cc1ccc([C@H](NC(=O)c2ccc3cccnc3c2)c2ncccc2C(F)(F)F)cc1
# ORCA input file 'CHEMBL4245611.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5279438: CCOC(=O)c1cnc(-c2ccccc2)s1
# ORCA input file 'CHEMBL5279438.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5273282: CCOC(=O)c1sc(-c2cccc(F)c2)nc1O
# ORCA input file 'CHEMBL5273282.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5281922: COc1cccc(NS(=O)(=O)c2c(C)cc(C)c([N+](=O)[O-])c2C)c1
# ORCA input file 'CHEMBL5281922.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5289538: COC(=O)c1nc(-c2ccccc2)sc1O
# ORCA input file 'CHEMBL5289538.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5269570: CCn1nnc(-c2sc(-c3cccc(C)c3)nc2O)n1
# ORCA input file 'CHEMBL5269570.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5274774: C[C@H](N)[C@H](O)C/C=C\C/C=C\C/C=C\C/C=C\C/C=C\C/C=C\CCCCCC[C@@H](O)[C@H](C)N
# ORCA input file 'CHEMBL5274774.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL190461: C=C(C)[C@@H]1CCC(C)=C[C@H]1c1c(O)cc(CCCCC)cc1O
# ORCA input file 'CHEMBL190461.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5290143: CCOC(=O)c1sc(-c2ccccc2)nc1CO
# ORCA input file 'CHEMBL5290143.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5285119: Cc1c(N(Cc2ccc(OC(F)(F)F)cc2)S(=O)(=O)CCN2CCC(c3ccccc3)CC2)sc2ccccc12
# ORCA input file 'CHEMBL5285119.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5291176: CON(C)C(=O)c1sc(-c2ccccc2O)nc1O
# ORCA input file 'CHEMBL5291176.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL3687409: CNC(=O)c1ccc(S(=O)(=O)N(Cc2ccc(OC(F)(F)F)cc2)c2ncc3ccccc3c2C)cc1
# ORCA input file 'CHEMBL3687409.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5093646: CCOC(=O)c1sc(-c2cccc(F)c2)nc1C#CCCCC(=O)O
# ORCA input file 'CHEMBL5093646.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5274341: CC(C)OP(=O)(OC(C)C)[C@@H](Cc1ccc(F)c(C(F)(F)F)c1)c1sc2ccccc2c1Br
# ORCA input file 'CHEMBL5274341.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5280999: CCOC(=O)c1ccc(-c2cccc(F)c2)cc1O
# ORCA input file 'CHEMBL5280999.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5284655: CC(=O)c1sc(-c2cccc(F)c2)nc1O
# ORCA input file 'CHEMBL5284655.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5267628: O=C(c1sc(-c2cccc(F)c2)nc1O)N1CCCCCO1
# ORCA input file 'CHEMBL5267628.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5282295: CSc1cc(-c2ccc(Cl)cc2)[nH]n1
# ORCA input file 'CHEMBL5282295.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5283563: CCN(C)C(=O)c1sc(-c2ccccc2)nc1O
# ORCA input file 'CHEMBL5283563.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5266721: Cc1ccc2nc(C(F)(F)F)n(-c3ccc(C(=O)CN4C(=O)NC5(CCC(F)(F)CC5)C4=O)cc3)c2n1
# ORCA input file 'CHEMBL5266721.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5287298: CCN(C(=O)/C=C/c1cccc([N+](=O)[O-])c1)c1ccccc1
# ORCA input file 'CHEMBL5287298.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5279842: CCON(C)C(=O)c1sc(-c2cccc(F)c2)nc1O
# ORCA input file 'CHEMBL5279842.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5278729: Cn1nnc(-c2sc(-c3cccc(F)c3)nc2O)n1
# ORCA input file 'CHEMBL5278729.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5268544: CCn1nnc(-c2sc(-c3c(Cl)cccc3Cl)nc2O)n1
# ORCA input file 'CHEMBL5268544.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5277700: CCOC(=O)c1sc(-c2ccccc2)nc1N
# ORCA input file 'CHEMBL5277700.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5279560: O=C(c1sc(-c2ccccc2O)nc1O)N1CCCCO1
# ORCA input file 'CHEMBL5279560.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL465: CCCCCc1cc(O)c2c(c1)OC(C)(C)[C@@H]1CCC(C)=C[C@@H]21
# ORCA input file 'CHEMBL465.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5276539: O=C(O)c1sc(-c2ccccc2)nc1O
# ORCA input file 'CHEMBL5276539.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5268431: CCOC(=O)c1sc(-c2ccc(C)cc2)nc1O
# ORCA input file 'CHEMBL5268431.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5279823: CCn1nnc(-c2sc(-c3ccc(F)cc3)nc2O)n1
# ORCA input file 'CHEMBL5279823.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5287528: Oc1nc(-c2cccc(F)c2)sc1-c1nn[nH]n1
# ORCA input file 'CHEMBL5287528.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5270159: CCn1nnc(-c2sc(-c3ccc(O)cc3)nc2O)n1
# ORCA input file 'CHEMBL5270159.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5266190: CCCC(=O)c1sc(-c2cccc(F)c2)nc1O
# ORCA input file 'CHEMBL5266190.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5284265: CCCCC/C=C/C/C=C\C/C=C/C/C=C/CCCC(=O)NCCc1ccc(O)c(O)c1
# ORCA input file 'CHEMBL5284265.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL808: Clc1ccc(COC(Cn2ccnc2)c2ccc(Cl)cc2Cl)cc1
# ORCA input file 'CHEMBL808.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5268297: Cc1nnc(-c2sc(-c3cccc(F)c3)nc2O)o1
# ORCA input file 'CHEMBL5268297.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL1779158: c1ccc(CN(CCc2c[nH]c3ccccc23)Cc2ccccc2)cc1
# ORCA input file 'CHEMBL1779158.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5279232: CCOC(=O)Cc1sc(-c2ccccc2)nc1O
# ORCA input file 'CHEMBL5279232.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5282352: CCn1nnc(-c2sc(-c3cccc(N)c3)nc2O)n1
# ORCA input file 'CHEMBL5282352.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL207433: O=C(Nc1ccccc1Br)N[C@@H]1CCN(c2ccc(C(F)(F)F)cn2)C1
# ORCA input file 'CHEMBL207433.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL1377190: CCOC(=O)c1sc(-c2ccc(Cl)cc2)nc1O
# ORCA input file 'CHEMBL1377190.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5275535: CCn1nnc(-c2sc(-c3cnccn3)nc2O)n1
# ORCA input file 'CHEMBL5275535.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5269450: CC(C)CC(=O)c1sc(-c2cccc(F)c2)nc1O
# ORCA input file 'CHEMBL5269450.inp' generated successfully with charge 0 and multiplicity 1.
# Processing CHEMBL5289662: CCON(C)C(=O)c1sc(-c2ccccc2O)nc1O
# ORCA input file 'CHEMBL5289662.inp' generated successfully with charge 0 and multiplicity 1.

# %% [markdown]
# # Run Orca

# %%
def run_orca_batch(input_folder,output_folder):
    """
    This function will search for all .inp files in the specified folder, 
    run ORCA on each, and generate corresponding .out files.
    """
    # List all files in the directory
    for file_name in os.listdir(input_folder):
        if file_name.endswith(".inp"):
            # Get the base name without the .inp extension
            base_name = os.path.splitext(file_name)[0]
            inp_file = os.path.join(input_folder, file_name)
            out_file = os.path.join(input_folder, f"{base_name}.out")
            
            # Run ORCA and redirect output to the .out file
            if not os.path.exists(output_folder):
                os.makedirs(output_folder)
                print(f"Directory '{output_folder}' created.")
            else:
                print(f"Directory '{output_folder}' already exists.")
            
            print(f"Processing: {file_name}")
            with open(f"{output_folder}/{out_file}", "w") as out_f:
                subprocess.run(["orca_path/orca_6_0_0/orca", inp_file], stdout=out_f)

# Example: Set the folder containing .inp files
input_folder = "orca_inputs/"  # Replace with the correct folder path
output_folder = "orca_outputs"
# Run the batch process
run_orca_batch(input_folder,output_folder)

# %% [markdown]
# # Extract Quantum Descriptors

# %%
def extract_homo_lumo(orca_output_file):
    """
    Extracts the HOMO and LUMO energies from an ORCA output file.

    Args:
    orca_output_file (str): Path to the ORCA output file.

    Returns:
    tuple: HOMO and LUMO energies, or (None, None) if not found.
    """
    try:
        with open(orca_output_file, 'r') as f:
            lines = f.readlines()
        
        homo_energy = None
        lumo_energy = None
        orbital_energies = []
        start_index = None

        # Find the section that contains "NO   OCC          E(Eh)            E(eV)"
        for i, line in enumerate(lines):
            if "  NO   OCC          E(Eh)            E(eV)" in line:
                start_index = i
                break

        if start_index is None:
            print(f"No 'ORBITAL ENERGIES' section found in {orca_output_file}")
            return None, None

        # Extract orbital energies from the section
        for line in lines[start_index + 1:]:
            if "---" in line or line.strip() == "":  # End of section
                break

            parts = line.split()
            if len(parts) == 4:
                occ = float(parts[1])  # Occupation number
                energy = float(parts[2])  # Energy in Eh (Hartrees)
                orbital_energies.append((occ, energy))

        # Identify HOMO (last occupied orbital) and LUMO (first unoccupied orbital)
        for i, (occ, energy) in enumerate(orbital_energies):
            if occ == 2.00:
                homo_energy = energy
            if occ == 0.00 and lumo_energy is None:
                lumo_energy = energy

        return homo_energy, lumo_energy
    except Exception as e:
        print(f"Error processing file {orca_output_file}: {e}")
        return None, None

def calculate_quantum_descriptors(homo, lumo):
    """
    Calculates electronegativity and chemical hardness based on HOMO and LUMO energies.

    Args:
    homo (float): HOMO energy.
    lumo (float): LUMO energy.

    Returns:
    tuple: Electronegativity and chemical hardness.
    """
    if homo is None or lumo is None:
        return None, None

    # Electronegativity (χ) and Chemical Hardness (η)
    electronegativity = - (homo + lumo) / 2
    hardness = (lumo - homo) / 2

    return electronegativity, hardness

def process_folder_and_save_csv_as_new(folder_path, original_csv_file, updated_csv_file):
    """
    Processes all ORCA .out files in a given folder, extracts HOMO/LUMO, and saves to a new CSV file.

    Args:
    folder_path (str): Path to the folder containing .out files.
    original_csv_file (str): Path to the original CSV file.
    updated_csv_file (str): Path to save the updated CSV file.
    """
    # Load the CSV file
    df = pd.read_csv(original_csv_file)[['Molecule ChEMBL ID']]

    # use the first column as the identifier column
    identifier_column = df.columns[0]

    if 'HOMO' not in df.columns:
        df['HOMO'] = None
    if 'LUMO' not in df.columns:
        df['LUMO'] = None
    if 'Electronegativity' not in df.columns:
        df['Electronegativity'] = None
    if 'Hardness' not in df.columns:
        df['Hardness'] = None

    # Process each .out file in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(".out"):
            file_path = os.path.join(folder_path, filename)

            # Extract HOMO and LUMO energies from the .out file
            homo, lumo = extract_homo_lumo(file_path)

            if homo is not None and lumo is not None:
                # Calculate electronegativity and hardness
                electronegativity, hardness = calculate_quantum_descriptors(homo, lumo)

                # Use the first column to match the file
                file_id = os.path.splitext(filename)[0]

                # Update the CSV for the corresponding row
                df.loc[df[identifier_column] == file_id, 'HOMO'] = homo
                df.loc[df[identifier_column] == file_id, 'LUMO'] = lumo
                df.loc[df[identifier_column] == file_id, 'Electronegativity'] = electronegativity
                df.loc[df[identifier_column] == file_id, 'Hardness'] = hardness

    # Save the updated CSV file with a new name
    df.to_csv(updated_csv_file, index=False)
    print(f"Updated CSV file saved as {updated_csv_file}")

# Example usage:
folder_path = "orca_outputs/"  # Path to folder containing .out files
original_csv_file = "../1_preprocess/1_TRPM8-homosapien-compounds-activities-processed.csv"  # Path to your original CSV file
updated_csv_file = "quantum-descriptors.csv"  # Path to save the updated CSV
process_folder_and_save_csv_as_new(folder_path, original_csv_file, updated_csv_file)

# %%
# Load the CSV file
df = pd.read_csv("quantum-descriptors.csv")

# Select the quantum descriptor columns for standardization
quantum_columns = ['HOMO', 'LUMO', 'Electronegativity', 'Hardness']

scaler = StandardScaler()
df[quantum_columns] = scaler.fit_transform(df[quantum_columns])

df.to_csv("quantum-descriptors-standardized.csv", index=False)
print("Standardized data saved as standardized_updated.csv")

# %% [markdown]
# # Find Mean Absolute Deviation (MAD) and variance and append to CSV

# %%
import os
import numpy as np
import pandas as pd

def process_orca_outputs_and_append_to_csv(folder_path, csv_file_path, output_csv_file_path):
    # Load the existing CSV file
    df = pd.read_csv(csv_file_path)
    
    # Create new columns for Variance and MAD if they don't exist
    if 'Variance' not in df.columns:
        df['Variance'] = np.nan  
    if 'MAD' not in df.columns:
        df['MAD'] = np.nan  
    # Loop through all ORCA output files in the specified folder
    for filename in os.listdir(folder_path):
        if filename.endswith('.out'):
            file_path = os.path.join(folder_path, filename)
            
            with open(file_path, 'r') as file:
                lines = file.readlines()
                collect_charges = False
                mulliken_charges = []  # store Mulliken charges
                
                # Find and process the Mulliken atomic charges section
                for i, line in enumerate(lines):
                    if 'MULLIKEN ATOMIC CHARGES' in line:
                        collect_charges = True
                        continue  # Move to the next line after finding the section
                    elif collect_charges:
                        # Stop collecting charges when you reach "Sum of atomic charges"
                        if 'Sum of atomic charges' in line:
                            break
                        # Extract charges following the ":" symbol
                        try:
                            split_line = line.split(':')
                            if len(split_line) == 2:
                                charge = float(split_line[1].strip().split()[0])
                                mulliken_charges.append(charge)
                        except ValueError:
                            continue  # Skip lines that do not match the format
                
                # Calculate variance and MAD if charges were found
                if mulliken_charges:
                    variance_charge = np.var(mulliken_charges)
                    mad_charge = np.mean(np.abs(mulliken_charges - np.mean(mulliken_charges)))
                    
                    # Append the variance and MAD to the CSV DataFrame based on file name match
                    file_name_without_ext = filename.replace('.out', '')
                    # Locate the matching row based on the filename in the first column of the existing csv
                    if file_name_without_ext in df.iloc[:, 0].values:
                        df.loc[df.iloc[:, 0] == file_name_without_ext, 'Variance'] = variance_charge
                        df.loc[df.iloc[:, 0] == file_name_without_ext, 'MAD'] = mad_charge
                    else:
                        print(f"File name {file_name_without_ext} not found in CSV file.")
    
    # Save the updated DataFrame to a new CSV file
    df.to_csv(output_csv_file_path, index=False)
    print(f"Updated CSV file saved as {output_csv_file_path}")

# Example usage:
folder_path = 'orca_outputs/'  # Replace with the path to your ORCA output files
csv_file_path = 'quantum-descriptors-standardized.csv'  # Replace with the path to your existing CSV file
output_csv_file_path = 'quantum-descriptors-standardized_updated_wParital_charges.csv'  # Replace with the path to save the new CSV file

process_orca_outputs_and_append_to_csv(folder_path, csv_file_path, output_csv_file_path)
