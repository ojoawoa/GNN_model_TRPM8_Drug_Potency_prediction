# %% [markdown]
# Split graph dataset into 80% train, 10% test, 10% validation

# %%
import torch
from torch.utils.data import random_split
import os

# --- Settings ---
task_name = "classification"  # Change to "regression" when needed
#task_name = "regression"  # Change to "regression" when needed
input_file = f"../3_graph_data/TRPM8_{task_name}_graph_dataset.pt"
output_dir = f"../4_train_test_split/random_split/{task_name}"

# --- Load data ---
data_list = torch.load(input_file)
print(data_list)
# --- Split sizes ---
total_len = len(data_list)
train_size = int(0.8 * total_len)
val_size = int(0.1 * total_len)
test_size = total_len - train_size - val_size

train_set, val_set, test_set = random_split(data_list, [train_size, val_size, test_size])

# --- Save output ---
os.makedirs(output_dir, exist_ok=True)
torch.save(train_set, os.path.join(output_dir, f"{task_name}_train.pt"))
torch.save(val_set, os.path.join(output_dir, f"{task_name}_val.pt"))
torch.save(test_set, os.path.join(output_dir, f"{task_name}_test.pt"))

print(f"✅ Saved {task_name} splits to '{output_dir}'")
print(f"   📦 Train: {len(train_set)} | Val: {len(val_set)} | Test: {len(test_set)}")
# Out:
# C:\Users\johng23\AppData\Local\Temp\ipykernel_17196\1054913882.py:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data_list = torch.load(input_file)
# [Data(x=[31, 19], edge_index=[2, 68], edge_attr=[68, 10], y=[1]), Data(x=[30, 19], edge_index=[2, 64], edge_attr=[64, 10], y=[1]), Data(x=[33, 19], edge_index=[2, 74], edge_attr=[74, 10], y=[1]), Data(x=[30, 19], edge_index=[2, 66], edge_attr=[66, 10], y=[1]), Data(x=[27, 19], edge_index=[2, 58], edge_attr=[58, 10], y=[1]), Data(x=[29, 19], edge_index=[2, 62], edge_attr=[62, 10], y=[1]), Data(x=[24, 19], edge_index=[2, 54], edge_attr=[54, 10], y=[1]), Data(x=[26, 19], edge_index=[2, 60], edge_attr=[60, 10], y=[1]), Data(x=[30, 19], edge_index=[2, 66], edge_attr=[66, 10], y=[1]), Data(x=[25, 19], edge_index=[2, 54], edge_attr=[54, 10], y=[1]), Data(x=[40, 19], edge_index=[2, 86], edge_attr=[86, 10], y=[1]), Data(x=[36, 19], edge_index=[2, 78], edge_attr=[78, 10], y=[1]), Data(x=[35, 19], edge_index=[2, 78], edge_attr=[78, 10], y=[1]), Data(x=[37, 19], edge_index=[2, 82], edge_attr=[82, 10], y=[1]), Data(x=[38, 19], edge_index=[2, 84], edge_attr=[84, 10], y=[1]), Data(x=[34, 19], edge_index=[2, 76], edge_attr=[76, 10], y=[1]), Data(x=[37, 19], edge_index=[2, 80], edge_attr=[80, 10], y=[1]), Data(x=[37, 19], edge_index=[2, 80], edge_attr=[80, 10], y=[1]), Data(x=[36, 19], edge_index=[2, 78], edge_attr=[78, 10], y=[1]), Data(x=[36, 19], edge_index=[2, 80], edge_attr=[80, 10], y=[1]), Data(x=[13, 19], edge_index=[2, 28], edge_attr=[28, 10], y=[1]), Data(x=[29, 19], edge_index=[2, 62], edge_attr=[62, 10], y=[1]), Data(x=[25, 19], edge_index=[2, 54], edge_attr=[54, 10], y=[1]), Data(x=[29, 19], edge_index=[2, 62], edge_attr=[62, 10], y=[1]), Data(x=[29, 19], edge_index=[2, 62], edge_attr=[62, 10], y=[1]), Data(x=[11, 19], edge_index=[2, 22], edge_attr=[22, 10], y=[1]), Data(x=[32, 19], edge_index=[2, 68], edge_attr=[68, 10], y=[1]), Data(x=[29, 19], edge_index=[2, 62], edge_attr=[62, 10], y=[1]), Data(x=[28, 19], edge_index=[2, 60], edge_attr=[60, 10], y=[1]), Data(x=[27, 19], edge_index=[2, 58], edge_attr=[58, 10], y=[1]), Data(x=[30, 19], edge_index=[2, 66], edge_attr=[66, 10], y=[1]), Data(x=[20, 19], edge_index=[2, 44], edge_attr=[44, 10], y=[1]), Data(x=[34, 19], edge_index=[2, 74], edge_attr=[74, 10], y=[1]), Data(x=[28, 19], edge_index=[2, 60], edge_attr=[60, 10], y=[1]), Data(x=[35, 19], edge_index=[2, 76], edge_attr=[76, 10], y=[1]), Data(x=[34, 19], edge_index=[2, 76], edge_attr=[76, 10], y=[1]), Data(x=[32, 19], edge_index=[2, 68], edge_attr=[68, 10], y=[1]), Data(x=[30, 19], edge_index=[2, 64], edge_attr=[64, 10], y=[1]), Data(x=[30, 19], edge_index=[2, 66], edge_attr=[66, 10], y=[1]), Data(x=[26, 19], edge_index=[2, 56], edge_attr=[56, 10], y=[1]), Data(x=[27, 19], edge_index=[2, 58], edge_attr=[58, 10], y=[1]), Data(x=[30, 19], edge_index=[2, 66], edge_attr=[66, 10], y=[1]), Data(x=[30, 19], edge_index=[2, 66], edge_attr=[66, 10], y=[1]), Data(x=[26, 19], edge_index=[2, 56], edge_attr=[56, 10], y=[1]), Data(x=[35, 19], edge_index=[2, 78], edge_attr=[78, 10], y=[1]), Data(x=[36, 19], edge_index=[2, 78], edge_attr=[78, 10], y=[1]), Data(x=[36, 19], edge_index=[2, 80], edge_attr=[80, 10], y=[1]), Data(x=[40, 19], edge_index=[2, 86], edge_attr=[86, 10], y=[1]), Data(x=[37, 19], edge_index=[2, 80], edge_attr=[80, 10], y=[1]), Data(x=[41, 19], edge_index=[2, 88], edge_attr=[88, 10], y=[1]), Data(x=[41, 19], edge_index=[2, 92], edge_attr=[92, 10], y=[1]), Data(x=[40, 19], edge_index=[2, 90], edge_attr=[90, 10], y=[1]), Data(x=[36, 19], edge_index=[2, 78], edge_attr=[78, 10], y=[1]), Data(x=[38, 19], edge_index=[2, 84], edge_attr=[84, 10], y=[1]), Data(x=[35, 19], edge_index=[2, 78], edge_attr=[78, 10], y=[1]), Data(x=[38, 19], edge_index=[2, 84], edge_attr=[84, 10], y=[1]), Data(x=[30, 19], edge_index=[2, 64], edge_attr=[64, 10], y=[1]), Data(x=[30, 19], edge_index=[2, 66], edge_attr=[66, 10], y=[1]), Data(x=[28, 19], edge_index=[2, 62], edge_attr=[62, 10], y=[1]), Data(x=[28, 19], edge_index=[2, 62], edge_attr=[62, 10], y=[1]), Data(x=[30, 19], edge_index=[2, 64], edge_attr=[64, 10], y=[1]), Data(x=[41, 19], edge_index=[2, 88 ...
# ✅ Saved classification splits to '../4_train_test_split/random_split/classification'
#    📦 Train: 423 | Val: 52 | Test: 54
